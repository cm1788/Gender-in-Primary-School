# %% [markdown]
# ### TODO:
#
# * try neewer version of spacy (e.g. different add_pipe syntax) - better dep_prser?
# * non-human character gender count (versus human) - better aggregation
# * add all female/male subjects (singular and plural) to verb clause detection e.g. ['she', 'girl', 'woman', 'mum', 'mother', 'lady', 'sister', 'daughter']
# * for found words, store in dataframe instead of lists (with metadata: character it relates to, book found in etc)
# * make tables for all word types
# * make wordlcouds
#
# ### TO DISCUSS:
# * other sentence structures to capture?
# * need validation?
#
# ### Other ideas:
# * how often does he/she appear as subject/object of verb clause?

# %% [markdown]
# ### Resources:
#
# - https://github.com/peter3125/enhanced-subject-verb-object-extraction (better than standard Spacy for subject-verb-object extraction)
# - https://nbviewer.jupyter.org/gist/nealcaren/5105037 (how the Times writes about men and women)
# - https://spacy.io/usage/linguistic-features
# - https://stackoverflow.com/questions/40288323/what-do-spacys-part-of-speech-and-dependency-tags-mean

# %%
TO_EXCLUDE = ['Mini Beasties', 'Ten in the Bed and Other Counting Rhymes', 'The Rescue Party', 'One Snowy Night', 'The Night Before Christmas', 'One Starry Night'] # Books that currently has issues in the excel file

# %%
import os
import pdfplumber
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import spacy
from spacy import displacy
from spacy.lang.en.examples import sentences 

# %matplotlib inline

# %%
nlp = spacy.load("en_core_web_lg")
#nlp.add_pipe(nlp.create_pipe('sentencizer'))
#nlp.add_pipe(nlp.create_pipe("parser"))

# %%
doc = nlp("The clever girl eats the red apple hungrily.")
#doc = nlp("He was lazy")

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# The the DET DT det Xxx True True
# clever clever ADJ JJ amod xxxx True False
# girl girl NOUN NN nsubj xxxx True False
# eats eat VERB VBZ ROOT xxxx True False
# the the DET DT det xxx True True
# red red ADJ JJ amod xxx True False
# apple apple NOUN NN dobj xxxx True False
# hungrily hungrily ADV RB advmod xxxx True False
# . . PUNCT . punct . False False

# %%
displacy.render(doc, style="dep", options={'distance':120});
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="db21796f52e7402db5e7d0c371572321-0" class="displacy" width="1010" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">clever</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">girl</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">eats</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">red</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">hungrily.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADV</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-db21796f52e7402db5e7d0c371572321-0-0" stroke-width="2px" d="M70,242.0 C70,122.0 280.0,122.0 280.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-db21796f52e7402db5e7d0c371572321-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,244.0 L62,232.0 78,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-db21796f52e7402db5e7d0c371572321-0-1" stroke-width="2px" d="M190,242.0 C190,182.0 275.0,182.0 275.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-db21796f52e7402db5e7d0c371572321-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,244.0 L182,232.0 198,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-db21796f52e7402db5e7d0c371572321-0-2" stroke-width="2px" d="M310,242.0 C310,182.0 395.0,182.0 395.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-db21796f52e7402db5e7d0c371572321-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,244.0 L302,232.0 318,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-db21796f52e7402db5e7d0c371572321-0-3" stroke-width="2px" d="M550,242.0 C550,122.0 760.0,122.0 760.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-db21796f52e7402db5e7d0c371572321-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,244.0 L542,232.0 558,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-db21796f52e7402db5e7d0c371572321-0-4" stroke-width="2px" d="M670,242.0 C670,182.0 755.0,182.0 755.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-db21796f52e7402db5e7d0c371572321-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,244.0 L662,232.0 678,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-db21796f52e7402db5e7d0c371572321-0-5" stroke-width="2px" d="M430,242.0 C430,62.0 765.0,62.0 765.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-db21796f52e7402db5e7d0c371572321-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M765.0,244.0 L773.0,232.0 757.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-db21796f52e7402db5e7d0c371572321-0-6" stroke-width="2px" d="M430,242.0 C430,2.0 890.0,2.0 890.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-db21796f52e7402db5e7d0c371572321-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M890.0,244.0 L898.0,232.0 882.0,232.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
sentences_examples = pd.DataFrame({
    'file_name': [],
    'directory': [],
    'book': [],
    'word_count': [],
    'text': []
})

def add_example_sentence(doc, directory, name, book, sentences_examples, dist=120):
    
    svg = displacy.render(doc, style="dep", options={'distance':dist}, jupyter=False)
    
    sentences_examples = sentences_examples.append(
        {'file_name': '%s.svg' % name, 
         'directory': directory, 
         'book': book, 
         'word_count': len(doc), 
         'text': doc.text},
        ignore_index=True
    )
    
    with open ('../code/example_spacy_sentences/%s/%s.svg' % (directory, name), mode='w', encoding='utf-8') as ofile:
        ofile.write(svg)
        
    return sentences_examples

# %%
sentences_examples = add_example_sentence(doc, 'examples', 'clever_girl', 'n/a', sentences_examples)

# %%
spacy.explain('dobj')
# Out:
# 'direct object'

# %%
sentences_examples
# Out:
#          file_name directory book  word_count  \
# 0  clever_girl.svg  examples  n/a         9.0
#
#                                            text
# 0  The clever girl eats the red apple hungrily.

# %%
#labels = pd.read_excel('../Book List Exel April.xlsx', sheet_name='Sheet1')
labels = pd.read_excel('../Book List Clean Titles.xlsx', sheet_name='Sheet1')
labels = labels.rename(columns={'Author ': 'Author'})
labels = labels.loc[~labels.Title.isin(TO_EXCLUDE)]
#labels.loc[labels.Title=='The Gruffalo']

# %%
os.chdir('../text_pdfs')

# %%
df = pd.DataFrame()

def grab_text(title, labels):
    
    start = labels.loc[labels.Title==title]['Starting Page']
    if len(start)==0:
        print(title, "no start")
        start = 0
    else:
        start = start.values[0]
    end = labels.loc[labels.Title==title]['Ending Page']
    if len(end)==0:
        print(title, "no end")
        end = 0
    else:
        end = end.values[0]
    
    title = title + '.pdf'
    all_text = ''
    with pdfplumber.open(title) as pdf:
        for i, page in enumerate(pdf.pages):
            if i+1 >= start and i < end:
                single_page_text = page.extract_text()

                if single_page_text is not None:
                    all_text = all_text + '\n' + single_page_text
                
    return all_text

df['Title'] = [file.split('.')[0] for file in os.listdir() if file.split('.')[1]=='pdf']
df['Text'] = [grab_text(title, labels) for title in df.Title]
# Out:
# The Night Before Christmas no start
# The Night Before Christmas no end
# One Starry Night no start
# One Starry Night no end
# The Rescue Party no start
# The Rescue Party no end
# Ten in the Bed and Other Counting Rhymes no start
# Ten in the Bed and Other Counting Rhymes no end
# Mini Beasties no start
# Mini Beasties no end
# One Snowy Night no start
# One Snowy Night no end

# %%
df.head()
# Out:
#                                   Title  \
# 0            The Night Before Christmas
# 1                          The Gruffalo
# 2  The Monstrous Tale of Celery Crumble
# 3                         Peace at Last
# 4           Barry The Fish With Fingers
#
#                                                 Text
# 0
# 1  \nA mouse took a stroll through the deep dark ...
# 2  \nHave you met Celery Crumble? \nThat’s her ri...
# 3  \n \nThe hour was late. \n \nMr Bear was tired...
# 4  \nPuffy the puffer fish, could blow \nthe BEST...

# %%
df = df.loc[df.Text != ''].reset_index()

# %%
len(df)
# Out:
# 161

# %% [markdown]
# #### Fix this to get the Gruffalo!

# %%
test = df.loc[0].Text.replace('\n', ' ').replace('  ', ' ')
#test[0:50]
test[51:98]
# Out:
# 'A fox saw the mouse and the mouse looked good. '

# %% [markdown]
# #### This is an example of it failing (mouse should be dobj in this sentence):
#
# Note: would this work better https://github.com/peter3125/enhanced-subject-verb-object-extraction

# %%
doc = nlp(test[51:98])
#doc = nlp(test[0:50])
#doc = nlp(test)

# for token in doc:
#     print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
#             token.shape_, token.is_alpha, token.is_stop)

# %%
displacy.render(doc, style="dep", options={'distance':100});
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="75e85cea8f764c52acda4580f67028cd-0" class="displacy" width="1050" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">fox</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">saw</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">mouse</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">mouse</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">looked</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">good.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75e85cea8f764c52acda4580f67028cd-0-0" stroke-width="2px" d="M70,202.0 C70,152.0 135.0,152.0 135.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75e85cea8f764c52acda4580f67028cd-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,204.0 L62,192.0 78,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75e85cea8f764c52acda4580f67028cd-0-1" stroke-width="2px" d="M170,202.0 C170,152.0 235.0,152.0 235.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75e85cea8f764c52acda4580f67028cd-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,204.0 L162,192.0 178,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75e85cea8f764c52acda4580f67028cd-0-2" stroke-width="2px" d="M370,202.0 C370,152.0 435.0,152.0 435.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75e85cea8f764c52acda4580f67028cd-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,204.0 L362,192.0 378,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75e85cea8f764c52acda4580f67028cd-0-3" stroke-width="2px" d="M470,202.0 C470,52.0 845.0,52.0 845.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75e85cea8f764c52acda4580f67028cd-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M470,204.0 L462,192.0 478,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75e85cea8f764c52acda4580f67028cd-0-4" stroke-width="2px" d="M470,202.0 C470,152.0 535.0,152.0 535.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75e85cea8f764c52acda4580f67028cd-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M535.0,204.0 L543.0,192.0 527.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75e85cea8f764c52acda4580f67028cd-0-5" stroke-width="2px" d="M670,202.0 C670,152.0 735.0,152.0 735.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75e85cea8f764c52acda4580f67028cd-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,204.0 L662,192.0 678,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75e85cea8f764c52acda4580f67028cd-0-6" stroke-width="2px" d="M470,202.0 C470,102.0 740.0,102.0 740.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75e85cea8f764c52acda4580f67028cd-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,204.0 L748.0,192.0 732.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75e85cea8f764c52acda4580f67028cd-0-7" stroke-width="2px" d="M270,202.0 C270,2.0 850.0,2.0 850.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75e85cea8f764c52acda4580f67028cd-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M850.0,204.0 L858.0,192.0 842.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75e85cea8f764c52acda4580f67028cd-0-8" stroke-width="2px" d="M870,202.0 C870,152.0 935.0,152.0 935.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75e85cea8f764c52acda4580f67028cd-0-8" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M935.0,204.0 L943.0,192.0 927.0,192.0" fill="currentColor"/

# %%
sentences_examples = add_example_sentence(doc, 'hard', 'hard_0', 'The Gruffalo', sentences_examples)

# %% [markdown]
# #### So, we want to get any he/she that appears, and the verbs and nouns that are associated with them.
#
# #### Then we will extend to use named entities also (with named characeters and their genders from the excel sheet).
#
# Other ideas:
# - get noun chunks
# - get adjectival modifiers (child of noun) for gendered nouns
# - get nsubj for each verb
# - get dobj for verbs with gendered nsubj

# %%
female_identifiers =['she', 'girl', 'woman', 'mum', 'mother', 'lady', 'sister', 'daughter',
                   'girls', 'women', 'mums', 'mothers', 'ladies', 'sisters', 'daughters']

male_identifiers = ['he', 'boy', 'man', 'dad', 'father', 'guy', 'brother', 'son',
                   'boys', 'men', 'dads', 'fathers', 'guys', 'brothers', 'sons']

# %%
doc = nlp(test)

# %%
test_female_verbs = list()
test_male_verbs = list()

for title, text in zip(df.Title, df.Text):
    text = ' '.join(text.replace('\n', ' ').split())
    doc = nlp(text)

    for possible_subject in doc:
            if possible_subject.dep_ == 'nsubj' and possible_subject.head.pos_ == 'VERB':
                
                if possible_subject.head.lemma_ == "’":
                    #print(possible_subject.head, [child for child in possible_subject.head.children])
                    #print(title)
                    lem = 'be'
                else:
                    lem = possible_subject.head.lemma_
                    
                #if possible_subject.lower_ == 'he':
                if possible_subject.lower_ in male_identifiers:
                    test_male_verbs.append(lem)
                #elif possible_subject.lower_ == 'she':    
                elif possible_subject.lower_ in female_identifiers:    
                    test_female_verbs.append(lem)

# %%
print(len(test_male_verbs))
print(len(test_female_verbs))

# with 70 books it was 757 and 249
# Out:
# 1545
# 606

# %%
N = 30

def bar_word_freqs(word_list, title, N=N, normaliser=None):
    vf = Counter(word_list)
    total = int(sum(vf.values()))
    y = [count for tag, count in vf.most_common(N)]
    x = [tag for tag, count in vf.most_common(N)]
    
    if normaliser is not None:
        y = [yi / normaliser for yi in y]

    plt.bar(x, y, color='crimson')
    plt.title(title)
    plt.ylabel("Frequency (log scale)")
    plt.yscale('log')
    plt.xticks(rotation=90)
    for i, (tag, count) in enumerate(vf.most_common(N)):
        
        _count = count
        
        if normaliser is not None:
            _count = _count / normaliser
        
        if _count % 1 == 0:
            display = '%d' % _count
        else:
            display = '%.3f' % _count
            
        plt.text(i, _count, display, rotation=90,
                 ha='center', va='bottom', 
                 color='black')
#                  ha='center', va='top' if count < 6 else 'bottom', 
#                  color='white' if count < 6 else 'black')
    plt.xlim(-0.6, len(x)-0.4)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
bar_word_freqs(test_female_verbs, "Female verb frequencies")

plt.subplot(1,2,2)
bar_word_freqs(test_male_verbs, "Male verb frequencies")

plt.tight_layout()

# %% [markdown]
# #### Now we do the same, but including the named characters.
#
# And we extract the following words (see diagrams below):
# - verb associated with the noun subject in each sentence (nsubj)
# - adverbs associated with that verb (advmod)
# - nouns that are the object of the verb (dobj)
# - adjectives associated with the noun subject (amod and acomp)

# %% [markdown]
# #### To clarify the word types:

# %%
demo_sentence = "She ate the dark chocolate hungrily."
doc = nlp(demo_sentence)
displacy.render(doc, style="dep", options={'distance':120});
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c20d08f3c8a84cd0a6d7a57f0dd52e9b-0" class="displacy" width="770" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">She</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">ate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">dark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">chocolate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">hungrily.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADV</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c20d08f3c8a84cd0a6d7a57f0dd52e9b-0-0" stroke-width="2px" d="M70,242.0 C70,182.0 155.0,182.0 155.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c20d08f3c8a84cd0a6d7a57f0dd52e9b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,244.0 L62,232.0 78,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c20d08f3c8a84cd0a6d7a57f0dd52e9b-0-1" stroke-width="2px" d="M310,242.0 C310,122.0 520.0,122.0 520.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c20d08f3c8a84cd0a6d7a57f0dd52e9b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,244.0 L302,232.0 318,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c20d08f3c8a84cd0a6d7a57f0dd52e9b-0-2" stroke-width="2px" d="M430,242.0 C430,182.0 515.0,182.0 515.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c20d08f3c8a84cd0a6d7a57f0dd52e9b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,244.0 L422,232.0 438,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c20d08f3c8a84cd0a6d7a57f0dd52e9b-0-3" stroke-width="2px" d="M190,242.0 C190,62.0 525.0,62.0 525.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c20d08f3c8a84cd0a6d7a57f0dd52e9b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M525.0,244.0 L533.0,232.0 517.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c20d08f3c8a84cd0a6d7a57f0dd52e9b-0-4" stroke-width="2px" d="M190,242.0 C190,2.0 650.0,2.0 650.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c20d08f3c8a84cd0a6d7a57f0dd52e9b-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,244.0 L658.0,232.0 642.0,232.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
demo_sentence = "The fat mouse looked good."
doc = nlp(demo_sentence)
displacy.render(doc, style="dep", options={'distance':120});
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c6c8cbd81454434a96bb81b74b02c3f1-0" class="displacy" width="650" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">fat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">mouse</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">looked</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">good.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c6c8cbd81454434a96bb81b74b02c3f1-0-0" stroke-width="2px" d="M70,122.0 C70,2.0 290.0,2.0 290.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c6c8cbd81454434a96bb81b74b02c3f1-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,124.0 L62,112.0 78,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c6c8cbd81454434a96bb81b74b02c3f1-0-1" stroke-width="2px" d="M190,122.0 C190,62.0 285.0,62.0 285.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c6c8cbd81454434a96bb81b74b02c3f1-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,124.0 L182,112.0 198,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c6c8cbd81454434a96bb81b74b02c3f1-0-2" stroke-width="2px" d="M310,122.0 C310,62.0 405.0,62.0 405.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c6c8cbd81454434a96bb81b74b02c3f1-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,124.0 L302,112.0 318,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c6c8cbd81454434a96bb81b74b02c3f1-0-3" stroke-width="2px" d="M430,122.0 C430,62.0 525.0,62.0 525.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c6c8cbd81454434a96bb81b74b02c3f1-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M525.0,124.0 L533.0,112.0 517.0,112.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
labels['Protagonist Gender'].unique()
# Out:
# array([nan, 'F/M/M', 'M', 'NGS PLURAL', 'M/M', 'F', 'NGS FIRST PERSON',
#        'M/F', 'NA ', 'M ', 'NGS', 'F/M', 'F/M ', 'M/F/F/M/F/M/F/F/M',
#        'M PLURAL ', 'M  ', 'NA 2nd Person', 'M/F ',
#        '2nd person voice/NGS', 'NGS/NGS ', 'NA plural', 'F ',
#        'M/NGS/NGS/NGS/NGS', 'NA First Person', 'Na Direct Address',
#        'Many NGS',
#        'M/M/M/M/F/M/M/F/M/F/M/M/F/NGS/NGS/NGS/M/NGS/M/M/NGS/M/M/NGS',
#        'NA Second person', 'F first person', 'NA Direct Address',
#        'NA Direct address', 'NGS SINGULAR AND PLURAL', 'NGS MANY',
#        'na direct address', 'F/M/M/M'], dtype=object)

# %%
labels['Protagonist Name'].unique()
# Out:
# array([nan, 'Sarah/Percy/Bill', 'Eddy', 'we', 'Mr Bear; Gruff the Grump',
#        'Percy', 'Big Bear/Little Bear', 'Father Christmas', 'I/We',
#        'Grinch ', 'Santa', 'Mary', 'I', 'innkeeper',
#        'her baby;little dove/mother dove', 'Elmer', 'Cinder', 'Marlon',
#        'Jake', 'Sir Charlie ', 'Crossfire', 'Harry', 'monkey',
#        'snail / whale', 'Troll', 'McTat ', 'witch', 'little old lady',
#        'Superworm', 'Mouse', "Gruffalo's child", 'Charlie Cook',
#        'Night Monkey/Day Monkey ', 'Norman', 'duck',
#        'Tom thumb/Mother Hubbard/Cinderella/Baby Bunting/Bo-peep/Jack/Jill/Wicked Witch/Robin Hood',
#        'Sid', 'dinos;dinosaurs/cavemen', 'Kipper', 'Duck', 'you',
#        'Matilda; Tilda', 'Postman', 'Dave/Dogger', 'boy', 'boy/penguin',
#        'Supertato', 'Mr. Grinling; Mr Grinling', 'Baby bear', 'Arthur',
#        'Kipper ', 'little creature;bear', 'Mr Bear', 'Mr Large/Mrs Large',
#        'Wibbly Pig; Wibbly', 'Timothy;Tim', 'dog/frog', 'the farmer',
#        'ladybird', 'Tadpole', 'Squash', 'caterpillar', 'Caterpillars',
#        'spider', 'Scramble', 'ladybird/it', 'butterfly', 'Noi ', 'Syd',
#        'Danny/dinosaur dino', 'Button/Mungo/Papa', 'Ollie',
#        'Badger/animals/Rabbit/Fox/Mice/Robin', 'I ', 'Hare/Fox',
#        'Bubble/Squeak', 'Archie', 'Bear/Frog', 'Esme/Bear',
#        'Edmund/Bernard/Bob/Cup/Delilah/Ferdinand/Leopold/Helen/inventor/Jemima/The King/Jack Stack/Mary/owl/octopus/Parsnip/cucumber/typist/Nigel/Victor/Whiraffe/Xavier/Yeti/Yak',
#        'Jasper', 'crocodile', 'Mole;Daddy',
#        'the biggest furriest one; the polar bear; the animal', 'you/we',
#        'Eliza Jane', 'Guy', 'Sophie', 'Frog', 'pea ', 'We',
#        'Scruffy Bear', 'Cyril/Bruce', 'Wilf', 'I/we', 'I;Alex;Alexander',
#        'I;Amelia', 'Monkey', 'Lenny', "I;I've;Maisy", 'June', 'Pearl/Zog',
#        'Sugarlump', 'Stick Man', 'George', 'Janet / Bill', 'Zog',
#        'Ladybird', 'Ellen', 'girl', 'Gordon;little balloon', 'Bernard',
#        'Barry', 'Doug', 'Keith', 'Snow White', 'Beauty', 'Old Wise',
#        'Hippo', 'Ruby', 'Celery', 'Eleanor', 'Lion', 'Elephant', 'Jack',
#        'Ravi', 'Giraffe', 'Tiger', 'the Enormous Crocodile ',
#        'seventh duckling; sad little duckling; ugly duckling',
#        'Goldilocks', 'little old man/little old woman',
#        'Little Red Riding Hood',
#        'mother pig/first little pig;pigs/second little pig;pigs/third little pig;pigs'],
#       dtype=object)

# %%
female_verbs = list()
male_verbs = list()

female_ads = list()
male_ads = list()

female_advs = list()
male_advs = list()

female_nouns = list()
male_nouns = list()

def add_words(noun, adv, adj, noun_list, adv_list, adj_list):
    if noun is not None:
        noun_list.append(noun)
    if adv is not None:
        adv_list.append(adv)
    if adj is not None:
        adj_list.append(adj)
        
    return noun_list, adv_list, adj_list

for title, text in zip(df.Title, df.Text):
    text = text.replace('\n', ' ')
    doc = nlp(text)
    
    protagonist = labels.loc[labels.Title==title]['Protagonist Name'].values
    protagonist_gender = labels.loc[labels.Title==title]['Protagonist Gender'].values

    for possible_subject in doc:
            if possible_subject.dep_ == 'nsubj' and possible_subject.head.pos_ == 'VERB':
                
                if possible_subject.head.lemma_ == "’":
                    #print(possible_subject.head, [child for child in possible_subject.head.children])
                    #print(title)
                    lem = 'be'
                else:
                    lem = possible_subject.head.lemma_
                    
                noun = None
                adv = None
                adj = None
                for child in possible_subject.head.children:
                    if child.dep_ == 'dobj':
                        noun = child.lower_ #.lemma_
                    elif child.dep_ == 'acomp':
                        adj = child.lower_ #.lemma_
                    elif child.dep_ == 'advmod':
                        adv = child.lower_ #.lemma_
                    
                if possible_subject.lower_ in male_identifiers:
                    male_verbs.append(lem)
                    male_nouns, male_advs, male_ads = add_words(noun, adv, adj, male_nouns, male_advs, male_ads)
                    
                elif possible_subject.lower_ in female_identifiers:    
                    female_verbs.append(lem)
                    female_nouns, female_advs, female_ads = add_words(noun, adv, adj, female_nouns, female_advs, female_ads)
                    
                if len(protagonist) == 1 and isinstance(protagonist[0], str):
                    protagonist = protagonist[0].split('/')
                    protagonist_gender = protagonist_gender[0].split('/')
                    
                    for p, pg in zip(protagonist, protagonist_gender):
                        #print(p, pg)
                        if possible_subject.lower_ == p.lower():
                            if pg == 'M':
                                male_verbs.append(lem)
                                male_nouns, male_advs, male_ads = add_words(noun, adv, adj, male_nouns, male_advs, male_ads)
                            elif pg == 'F':
                                female_verbs.append(lem)
                                female_nouns, female_advs, female_ads = add_words(noun, adv, adj, female_nouns, female_advs, female_ads)
#                 if not(np.isnan(protagonist) and np.isnan(protagonist_gender)):
#                     if len(protagonist_gender.split('/')) == 1:

# %%
print("Without named protagonists we had: %d female verbs and %d male verbs." % (len(test_female_verbs), len(test_male_verbs)))
print("Now, with named protagonists we had: %d female verbs and %d male verbs." % (len(female_verbs), len(male_verbs)))

print("We also have:")

print("%d female adverbs and %d male adverbs" %(len(female_advs), len(male_advs)))
print("%d female adjectives and %d male adjectives" %(len(female_ads), len(male_ads)))
print("%d female nouns and %d male noun" %(len(female_nouns), len(male_nouns)))
# Out:
# Without named protagonists we had: 606 female verbs and 1545 male verbs.
# Now, with named protagonists we had: 722 female verbs and 2299 male verbs.
# We also have:
# 165 female adverbs and 573 male adverbs
# 14 female adjectives and 65 male adjectives
# 225 female nouns and 686 male noun

# %% [markdown]
# #### Normalising by the number of characters:
#
# Note: these numbers are computed in intial_analysis notebook

# %%
total_females = 155
total_males = 313

female_protagonists = 50
male_protagonists = 147

# %%
print(len(female_verbs) / female_protagonists, len(female_verbs))
print(len(male_verbs) / male_protagonists, len(male_verbs))

print(len(female_nouns) / female_protagonists, len(female_nouns))
print(len(male_nouns) / male_protagonists, len(male_nouns))

print(len(female_advs) / female_protagonists, len(female_advs))
print(len(male_advs) / male_protagonists, len(male_advs))

print(len(female_ads) / female_protagonists, len(female_ads))
print(len(male_ads) / male_protagonists, len(male_ads))
# Out:
# 14.44 722
# 15.639455782312925 2299
# 4.5 225
# 4.666666666666667 686
# 3.3 165
# 3.8979591836734695 573
# 0.28 14
# 0.4421768707482993 65

# %% [markdown]
# #### Previously with 70 books these numbers were:
#
# Without named protagonists we had: 249 female verbs and 757 male verbs.
# Now, with named protagonists we had: 293 female verbs and 1157 male verbs.
# We also have:
# 58 female adverbs and 278 male adverbs
# 6 female adjectives and 42 male adjectives
# 87 female nouns and 372 male noun

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
bar_word_freqs(female_verbs, "Female verb frequencies", normaliser=female_protagonists)

plt.subplot(1,2,2)
bar_word_freqs(male_verbs, "Male verb frequencies", normaliser=male_protagonists)

plt.tight_layout()

# %% [markdown]
# ### Here we grab some 'hard' example sentences to show to Fiona:
#
# #### Note: using strip() hear to remove trailing or leading spaces for improved performance.

# %%
# get all sentences in all texts, and their length in words
# select top 20 longest sentences
# output to file
# select top 20 shortest sentences
# output to file

# %%
sentences = pd.DataFrame()

book_col = []
sentences_col = []
length_col = []
index_col = []

for title, text in zip(df.Title, df.Text):
    text = text.replace('\n', ' ') # This is only safe provided the line break is not being used to separate sentences w/o puntctuation...
    text = ' '.join(text.split())
    
    doc = nlp(text)
    sentence_list = list(doc.sents)
    
    for si, sen in enumerate(sentence_list):
        book_col.append(title)
        
        doc = sen #nlp(sen.text.strip())
        sentences_col.append(doc)
        length_col.append(len(doc))
        index_col.append(si)

    
sentences['book'] = book_col
sentences['sentence_length'] = length_col
sentences['sentence'] = sentences_col
sentences['sentence_index'] = index_col

# %%
sentence_lenghts = sentences.groupby('sentence_length').agg({'book': 'count'}).rename(columns={'book': 'count'})

# %%
sentence_lenghts.head(15)
# Out:
#                  count
# sentence_length
# 1                  300
# 2                  347
# 3                  630
# 4                  728
# 5                  896
# 6                  850
# 7                 1001
# 8                 1010
# 9                  886
# 10                 925
# 11                 758
# 12                 696
# 13                 522
# 14                 421
# 15                 426

# %%
sentences.loc[4900].sentence
# Out:
# “If dOgS sit on logs, cats sit on gnats, bears sit on stairs, slugs sit on plugs, flies sit on pies, crickets sit on tickets, moths sit on cloths, leopards sit on shepherds, cheetahs sit on fajitas, gnus sit on canoes, Pigs sit on Wigs, boars sit on oars, whales sit on nails, dragons sit on wagons, mice sit on ice, kittens sit on mittens, puppies sit on guppies, crabs sit on kebabs, poodles sit on noodles, hornets sit on cornets, skunks sit on trunks, and elephants sit on smelly pants...”

# %%
plt.plot(sentence_lenghts.index, sentence_lenghts['count'])
plt.title('Distribution of sentence lenghts. \n (total of %d sentences)' % len(sentences))
plt.xlabel('sentence length')
plt.ylabel('frequency');

# %%
sentences = sentences.sort_values('sentence_length')

# %%
doc = sentences.loc[4900].sentence

# %%
displacy.render(doc, style="dep", options={'distance':120});
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="950a4b16c2f34b318c6d0622bf8d5b4c-0" class="displacy" width="11090" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">“</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">If</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">dOgS</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">sit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">logs,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">cats</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">sit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">gnats,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">bears</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">sit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">stairs,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">slugs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">sit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">plugs,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">flies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">sit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">pies,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">crickets</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">sit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">tickets,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">moths</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">sit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">cloths,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">leopards</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">NOUN</tspan>

# %%
for i in range(10):
    row = sentences.reset_index().loc[12412 - i]
    doc = row.sentence
    sentences_examples = add_example_sentence(doc, 'long', 'long_%d' % i, row.book, sentences_examples)

# %%
sentences_examples
# Out:
#           file_name directory  \
# 0   clever_girl.svg  examples
# 1        long_0.svg      long
# 2        long_1.svg      long
# 3        long_2.svg      long
# 4        long_3.svg      long
# 5        long_4.svg      long
# 6        long_5.svg      long
# 7        long_6.svg      long
# 8        long_7.svg      long
# 9        long_8.svg      long
# 10       long_9.svg      long
#
#                                                  book  word_count  \
# 0                                                 n/a        51.0
# 1                                             Oi Dog!       115.0
# 2                                         Tabby McTat        76.0
# 3                          The Smartest Giant in Town        70.0
# 4                          The Smartest Giant in Town        67.0
# 5                                         Boogie Bear        62.0
# 6   Sir Charlie Stinky Socks and the Really Big Ad...        56.0
# 7                              The Hungry Caterpillar        54.0
# 8                            Santa is Coming to Devon        51.0
# 9                     Super Sid The Silly Sausage Dog        51.0
# 10                              The Way Home For Wolf        51.0
#
#                                                  text
# 0   So he bowed to the narwhal, ox, walrus and goo...
# 1   “If dOgS sit on logs, cats sit on gnats, bears...
# 2   Now McTat had a wife and a very full life With...
# 3   George hopped on, singing to himself, “My tie ...
# 4   He hopped on, singing to himself, “My tie is a...
# 5   Oh dear, oh dear, oh oh dear, oh dear, dear, o...
# 6   Up the windy, windy staircase marched Sir Char...
# 7   On Saturday he ate throu gh one piece of choco...
# 8   He seemed to be arguing with a little box with...
# 9   He put his nose into the air and, without thin...
# 10  So he bowed to the narwhal, ox, walrus and goo...

# %% [markdown]
# # Not updated from here (31/10/2021)

# %%
dict(Counter(female_verbs))
# Out:
# {'go': 24,
#  'say': 137,
#  'think': 8,
#  'make': 15,
#  'invite': 1,
#  'want': 4,
#  'paint': 1,
#  'find': 12,
#  'wait': 4,
#  'unscrew': 1,
#  'enjoy': 1,
#  'learn': 3,
#  'need': 3,
#  'surprise': 1,
#  'like': 8,
#  'cook': 2,
#  'cry': 12,
#  'hold': 7,
#  'know': 7,
#  'love': 3,
#  'believe': 1,
#  'swoosh': 1,
#  'get': 9,
#  'tell': 13,
#  'leave': 2,
#  'whisper': 4,
#  'run': 7,
#  'could': 2,
#  'trip': 2,
#  'see': 8,
#  'wear': 5,
#  'forget': 3,
#  'thank': 1,
#  'live': 7,
#  'take': 15,
#  'open': 4,
#  'shoo': 1,
#  'shove': 1,
#  'huff': 1,
#  'puff': 1,
#  'push': 1,
#  'be': 22,
#  'come': 11,
#  'buy': 2,
#  'help': 2,
#  'call': 6,
#  'swoop': 3,
#  'lift': 2,
#  'sing': 1,
#  'let': 3,
#  'fear': 2,
#  'roll': 1,
#  'reach': 1,
#  'hoot': 1,
#  'coo': 1,
#  'sleep': 4,
#  'fly': 4,
#  'hop': 7,
#  'ask': 19,
#  'gasp': 1,
#  'lead': 1,
#  'teach': 1,
#  'ca': 1,
#  'laugh': 3,
#  'show': 1,
#  'give': 8,
#  'look': 17,
#  'search': 2,
#  'turn': 3,
#  'win': 3,
#  'keep': 4,
#  'listen': 1,
#  'hear': 5,
#  'walk': 2,
#  'start': 2,
#  'catch': 2,
#  'stop': 5,
#  'hug': 4,
#  'bite': 2,
#  'chop': 1,
#  'lay': 5,
#  'gaze': 3,
#  'sniff': 1,
#  'tiptoe': 3,
#  'speak': 1,
#  'decide': 2,
#  'decorate': 1,
#  'sit': 2,
#  'put': 12,
#  'hunt': 1,
#  'eat': 6,
#  'roar': 1,
#  'fight': 1,
#  'groom': 1,
#  'mind': 4,
#  'grow': 3,
#  'care': 1,
#  'yawn': 1,
#  'bring': 2,
#  'jump': 4,
#  'sob': 1,
#  'lie': 3,
#  'try': 12,
#  'approve': 1,
#  'write': 2,
#  'lose': 3,
#  'hiss': 1,
#  'slither': 2,
#  'prepare': 2,
#  'pack': 1,
#  'exclaim': 2,
#  'stand': 2,
#  'shout': 1,
#  'add': 2,
#  'send': 1,
#  'feel': 1,
#  'land': 2,
#  'answer': 9,
#  'finish': 1,
#  'fall': 1,
#  'ride': 2,
#  'stay': 1,
#  'wrap': 1,
#  'watch': 3,
#  'squeak': 1,
#  'tug': 1,
#  'insist': 1,
#  'said-': 2,
#  'skip': 1,
#  'wake': 2,
#  'wave': 2,
#  'stamp': 1,
#  'read': 2,
#  'grate': 1,
#  'talk': 1,
#  'agree': 1,
#  'appear': 1,
#  'cuddle': 1,
#  'have': 2,
#  'scoop': 2,
#  'sigh': 2,
#  'drift': 1,
#  'wobble': 1,
#  'topple': 1,
#  'clamber': 2,
#  'mutter': 1,
#  'hit': 1,
#  'soar': 1,
#  'choose': 1,
#  'smile': 2,
#  'stare': 1,
#  'kiss': 1,
#  'squash': 1,
#  'do': 2,
#  'stick': 1,
#  'rush': 2,
#  'sort': 1,
#  'use': 1,
#  'share': 1,
#  'chew': 1,
#  'understand': 1,
#  'drown': 1,
#  'hide': 2,
#  'wander': 1,
#  'blush': 2,
#  'mean': 1,
#  'joke': 2,
#  'touch': 1,
#  'squeeze': 1,
#  'munch': 1,
#  'crawl': 1,
#  'climb': 1,
#  'shed': 1,
#  'hang': 1,
#  'suck': 1,
#  'rest': 1,
#  'fix': 2,
#  'click': 1,
#  'beam': 1,
#  'tickle': 1,
#  'fen': 1,
#  'reply': 1,
#  'pause': 1,
#  'grab': 1,
#  'squirt': 2,
#  'protest': 1,
#  'pour': 1,
#  'splash': 1,
#  'giggle': 1,
#  'notice': 2,
#  'rip': 1,
#  'shake': 2,
#  'creep': 1,
#  'boil': 1,
#  'hope': 1,
#  'collect': 1,
#  'vow': 1,
#  'struggle': 1,
#  'stretch': 1,
#  'tidy': 1,
#  'dance': 1,
#  'squeal': 1,
#  'murmur': 1,
#  'stomp': 1,
#  'coil': 1,
#  'curl': 1,
#  'squawk': 1,
#  'leap': 1,
#  'croak': 1,
#  'begin': 2,
#  'swing': 1}

# %%
tfs = 16

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.title('Female verbs', fontsize=tfs)
wc = WordCloud(background_color='white').generate_from_frequencies(Counter(female_verbs))
plt.imshow(wc)
plt.axis('off');

plt.subplot(1,2,2)
plt.title('Male verbs', fontsize=tfs)
wc = WordCloud(background_color='white').generate_from_frequencies(Counter(male_verbs))
plt.imshow(wc)
plt.axis('off');

# %%
# ft = "Female noun frequencies"
# mt = "Male noun frequencies"
# fw = female_nouns
# mw = male_nouns

# ft = "Female adjective frequencies"
# mt = "Male adjective frequencies"
# fw = female_ads
# mw = male_ads

ft = "Female adverb frequencies"
mt = "Male adverb frequencies"
fw = female_advs
mw = male_advs

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
bar_word_freqs(fw, ft)

plt.subplot(1,2,2)
bar_word_freqs(mw, mt)

plt.tight_layout()

# %%
tfs = 16

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.title('Female nouns', fontsize=tfs)
wc = WordCloud(background_color='white').generate_from_frequencies(Counter(female_nouns))
plt.imshow(wc)
plt.axis('off');

plt.subplot(1,2,2)
plt.title('Male nouns', fontsize=tfs)
wc = WordCloud(background_color='white').generate_from_frequencies(Counter(male_nouns))
plt.imshow(wc)
plt.axis('off');

# %%
Counter(female_verbs).most_common(20)
# Out:
# [('say', 109),
#  ('be', 16),
#  ('go', 14),
#  ('make', 13),
#  ('take', 13),
#  ('look', 12),
#  ('tell', 11),
#  ('come', 10),
#  ('ask', 10),
#  ('find', 9),
#  ('answer', 9),
#  ('give', 8),
#  ('hop', 7),
#  ('put', 7),
#  ('think', 6),
#  ('like', 5),
#  ('eat', 5),
#  ('run', 5),
#  ('hold', 5),
#  ('buy', 4)]

# %% [markdown]
# #### Adjectival modifiers:

# %%
#demo_sentence = "All the people said very good, clever boy!"
demo_sentence = "Their new baby brother"
doc = nlp(demo_sentence)
displacy.render(doc, style="dep", options={'distance':120});
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="25acca3c0c6a4aa780605ed771a09d47-0" class="displacy" width="530" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Their</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">baby</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">brother</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-25acca3c0c6a4aa780605ed771a09d47-0-0" stroke-width="2px" d="M70,182.0 C70,2.0 410.0,2.0 410.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-25acca3c0c6a4aa780605ed771a09d47-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-25acca3c0c6a4aa780605ed771a09d47-0-1" stroke-width="2px" d="M190,182.0 C190,62.0 405.0,62.0 405.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-25acca3c0c6a4aa780605ed771a09d47-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,184.0 L182,172.0 198,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-25acca3c0c6a4aa780605ed771a09d47-0-2" stroke-width="2px" d="M310,182.0 C310,122.0 400.0,122.0 400.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-25acca3c0c6a4aa780605ed771a09d47-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,184.0 L302,172.0 318,172.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
female_adjs = list()
male_adjs = list()

for title, text in zip(df.Title, df.Text):
    text = text.replace('\n', ' ')
    doc = nlp(text)
    
    protagonist = labels.loc[labels.Title==title]['Protagonist Name'].values
    protagonist_gender = labels.loc[labels.Title==title]['Protagonist Gender'].values

    for possible_amod in doc:
            if possible_amod.dep_ == 'amod' and possible_amod.head.pos_ == 'NOUN':
                
#                 if possible_subject.head.lemma_ == "’":
#                     #print(possible_subject.head, [child for child in possible_subject.head.children])
#                     #print(title)
#                     lem = 'be'
#                 else:
#                     lem = possible_subject.head.lemma_
                lem = possible_amod.lemma_
                    
                if possible_amod.head.lower_ in male_identifiers:
                    male_adjs.append(lem)
                    #print(possible_amod.sent)
                    #print(possible_amod.head.lower_, lem)
                elif possible_amod.head.lower_ in female_identifiers:    
                    female_adjs.append(lem)
                    #print(possible_amod.head.lower_, lem)
                    
                if len(protagonist) == 1 and isinstance(protagonist[0], str):
                    protagonist = protagonist[0].split('/')
                    protagonist_gender = protagonist_gender[0].split('/')
                    
                    for p, pg in zip(protagonist, protagonist_gender):
                        if possible_amod.head.lower_ == p.lower():
                            #print(p.lower(), lem)
                            if pg == 'M':
                                male_adjs.append(lem)
                            elif pg == 'F':
                                female_adjs.append(lem)

# %%
print(len(female_adjs))
print(len(male_adjs))
# Out:
# 53
# 47

# %%
Counter(male_adjs).most_common(20)
# Out:
# [('little', 19),
#  ('old', 5),
#  ('wise', 5),
#  ('brown', 3),
#  ('scary', 2),
#  ('good', 2),
#  ('new', 2),
#  ('young', 1),
#  ('clever', 1),
#  ('cheeky', 1),
#  ('small', 1),
#  ('green', 1),
#  ('special', 1),
#  ('wet', 1),
#  ('asleep', 1),
#  ('grumpy', 1)]

# %%
Counter(female_adjs).most_common(20)
# Out:
# [('little', 17),
#  ('lazy', 11),
#  ('old', 8),
#  ('young', 3),
#  ('poor', 2),
#  ('naughty', 1),
#  ('bossy', 1),
#  ('big', 1),
#  ('thin', 1),
#  ('most', 1),
#  ('bad', 1),
#  ('ugly', 1),
#  ('silly', 1),
#  ('tiny', 1),
#  ('sweet', 1),
#  ('asleep', 1),
#  ('normal', 1)]

# %% [markdown]
# #### Including the adjectives from the previous caluse type (amod and acmop relating the nsubj)

# %%
fa = female_adjs + female_ads
ma = male_adjs + male_ads

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
bar_word_freqs(fa, "Female adjectives")

plt.subplot(1,2,2)
bar_word_freqs(ma, "Male adjectives")

plt.tight_layout()

# %%
tfs = 16

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.title('Female adjectives', fontsize=tfs)
wc = WordCloud(background_color='white').generate_from_frequencies(Counter(fa))
plt.imshow(wc)
plt.axis('off');

plt.subplot(1,2,2)
plt.title('Male adjectives', fontsize=tfs)
wc = WordCloud(background_color='white').generate_from_frequencies(Counter(ma))
plt.imshow(wc)
plt.axis('off');

# %% [markdown]
# ### Things to resolve:
#
# 1. Plural genders (e.g. cavemen)
# 2. Double barrel names (e.g. Stick Man, Charlie Cook etc)- replace with single token? (e.g. Stick_Man)
# 3. Add his/hers e.g. "His favourite food is roasted fox"
# 4. Add recognition of who is speaking. e.g. "I'm going to have lunch with a gruffalo"
#
# Need to do proper NER rather than just using nsubj?

# %% [markdown]
# #### Examples of sentence structures that are not currently being detected:

# %%
demo_sentence = "Charlie Cook was very hungry."
doc = nlp(demo_sentence)
displacy.render(doc, style="dep", options={'distance':120});
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2f6f68a67cd645bc85fe84ec6f6e73dd-0" class="displacy" width="650" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Charlie</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Cook</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">very</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">hungry.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2f6f68a67cd645bc85fe84ec6f6e73dd-0-0" stroke-width="2px" d="M70,122.0 C70,62.0 165.0,62.0 165.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2f6f68a67cd645bc85fe84ec6f6e73dd-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,124.0 L62,112.0 78,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2f6f68a67cd645bc85fe84ec6f6e73dd-0-1" stroke-width="2px" d="M190,122.0 C190,62.0 285.0,62.0 285.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2f6f68a67cd645bc85fe84ec6f6e73dd-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,124.0 L182,112.0 198,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2f6f68a67cd645bc85fe84ec6f6e73dd-0-2" stroke-width="2px" d="M430,122.0 C430,62.0 525.0,62.0 525.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2f6f68a67cd645bc85fe84ec6f6e73dd-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,124.0 L422,112.0 438,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2f6f68a67cd645bc85fe84ec6f6e73dd-0-3" stroke-width="2px" d="M310,122.0 C310,2.0 530.0,2.0 530.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2f6f68a67cd645bc85fe84ec6f6e73dd-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M530.0,124.0 L538.0,112.0 522.0,112.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
demo_sentence = "His favourite food is roasted fox."
doc = nlp(demo_sentence)
displacy.render(doc, style="dep", options={'distance':120});
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="155ea470d7514f8abb05a389162aa063-0" class="displacy" width="770" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">His</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">favourite</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">food</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">roasted</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">fox.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-155ea470d7514f8abb05a389162aa063-0-0" stroke-width="2px" d="M70,122.0 C70,2.0 290.0,2.0 290.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-155ea470d7514f8abb05a389162aa063-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,124.0 L62,112.0 78,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-155ea470d7514f8abb05a389162aa063-0-1" stroke-width="2px" d="M190,122.0 C190,62.0 285.0,62.0 285.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-155ea470d7514f8abb05a389162aa063-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,124.0 L182,112.0 198,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-155ea470d7514f8abb05a389162aa063-0-2" stroke-width="2px" d="M310,122.0 C310,62.0 405.0,62.0 405.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-155ea470d7514f8abb05a389162aa063-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,124.0 L302,112.0 318,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-155ea470d7514f8abb05a389162aa063-0-3" stroke-width="2px" d="M550,122.0 C550,62.0 645.0,62.0 645.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-155ea470d7514f8abb05a389162aa063-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,124.0 L542,112.0 558,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-155ea470d7514f8abb05a389162aa063-0-4" stroke-width="2px" d="M430,122.0 C430,2.0 650.0,2.0 650.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-155ea470d7514f8abb05a389162aa063-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,124.0 L658.0,112.0 642.0,112.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
demo_sentence = "It wasn't her best idea."
doc = nlp(demo_sentence)
displacy.render(doc, style="dep", options={'distance':120});
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="519cedc0592c45bd8b20962119d958f5-0" class="displacy" width="770" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">n't</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">her</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">best</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">idea.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-519cedc0592c45bd8b20962119d958f5-0-0" stroke-width="2px" d="M70,182.0 C70,122.0 160.0,122.0 160.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-519cedc0592c45bd8b20962119d958f5-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-519cedc0592c45bd8b20962119d958f5-0-1" stroke-width="2px" d="M190,182.0 C190,122.0 280.0,122.0 280.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-519cedc0592c45bd8b20962119d958f5-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">neg</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M280.0,184.0 L288.0,172.0 272.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-519cedc0592c45bd8b20962119d958f5-0-2" stroke-width="2px" d="M430,182.0 C430,62.0 645.0,62.0 645.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-519cedc0592c45bd8b20962119d958f5-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,184.0 L422,172.0 438,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-519cedc0592c45bd8b20962119d958f5-0-3" stroke-width="2px" d="M550,182.0 C550,122.0 640.0,122.0 640.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-519cedc0592c45bd8b20962119d958f5-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,184.0 L542,172.0 558,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-519cedc0592c45bd8b20962119d958f5-0-4" stroke-width="2px" d="M190,182.0 C190,2.0 650.0,2.0 650.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-519cedc0592c45bd8b20962119d958f5-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,184.0 L658.0,172.0 642.0,172.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
demo_sentence = "She said: 'I'm hungry.'"
doc = nlp(demo_sentence)
displacy.render(doc, style="dep", options={'distance':120});
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1502e9b2768d48dca3590c2aa1b1457d-0" class="displacy" width="650" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">She</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">said: '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">'m</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">hungry.'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1502e9b2768d48dca3590c2aa1b1457d-0-0" stroke-width="2px" d="M70,122.0 C70,62.0 165.0,62.0 165.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1502e9b2768d48dca3590c2aa1b1457d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,124.0 L62,112.0 78,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1502e9b2768d48dca3590c2aa1b1457d-0-1" stroke-width="2px" d="M310,122.0 C310,62.0 405.0,62.0 405.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1502e9b2768d48dca3590c2aa1b1457d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,124.0 L302,112.0 318,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1502e9b2768d48dca3590c2aa1b1457d-0-2" stroke-width="2px" d="M190,122.0 C190,2.0 410.0,2.0 410.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1502e9b2768d48dca3590c2aa1b1457d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M410.0,124.0 L418.0,112.0 402.0,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1502e9b2768d48dca3590c2aa1b1457d-0-3" stroke-width="2px" d="M430,122.0 C430,62.0 525.0,62.0 525.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1502e9b2768d48dca3590c2aa1b1457d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M525.0,124.0 L533.0,112.0 517.0,112.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
demo_sentence = "He was in the kitchen."
doc = nlp(demo_sentence)
displacy.render(doc, style="dep", options={'distance':120});
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d061475d4f2b45ab8d0815883e2725ce-0" class="displacy" width="650" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">He</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">kitchen.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d061475d4f2b45ab8d0815883e2725ce-0-0" stroke-width="2px" d="M70,122.0 C70,62.0 165.0,62.0 165.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d061475d4f2b45ab8d0815883e2725ce-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,124.0 L62,112.0 78,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d061475d4f2b45ab8d0815883e2725ce-0-1" stroke-width="2px" d="M190,122.0 C190,62.0 285.0,62.0 285.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d061475d4f2b45ab8d0815883e2725ce-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M285.0,124.0 L293.0,112.0 277.0,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d061475d4f2b45ab8d0815883e2725ce-0-2" stroke-width="2px" d="M430,122.0 C430,62.0 525.0,62.0 525.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d061475d4f2b45ab8d0815883e2725ce-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,124.0 L422,112.0 438,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d061475d4f2b45ab8d0815883e2725ce-0-3" stroke-width="2px" d="M310,122.0 C310,2.0 530.0,2.0 530.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d061475d4f2b45ab8d0815883e2725ce-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M530.0,124.0 L538.0,112.0 522.0,112.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ### Looking at speech:

# %%
for title, text in zip(df.Title, df.Text):
    text = text.replace('\n', ' ')
    doc = nlp(text)
    sentence_list = list(doc.sents)
    
    protagonist = labels.loc[labels.Title==title]['Protagonist Name'].values
    protagonist_gender = labels.loc[labels.Title==title]['Protagonist Gender'].values

    for possible_subject in doc:
            if possible_subject.dep_ == 'nsubj' and possible_subject.head.pos_ == 'VERB':
                
                if possible_subject.head.lemma_ == "say":
                    print('pre-previous:', sentence_list[sentence_list.index(possible_subject.sent)-2])
                    print('previous:', sentence_list[sentence_list.index(possible_subject.sent)-1])
                    print('current:', possible_subject.head.sent)
                    print('next:', sentence_list[sentence_list.index(possible_subject.sent)+1])
                    print(' ')
# Out:
# pre-previous: “Roasted fox!
# previous: I’m off!”
# current: Fox said.
# next: “Goodbye, little mouse," and away he sped.
#
# pre-previous: It’s    a gruffalo!" .
# previous: “My favourite food!"
# current: the Gruffalo said.
# next: “You'll    taste good on a slice of bread!”
#
# pre-previous: the Gruffalo said.
# previous: “You'll    taste good on a slice of bread!”
# current: Good?” said the mouse.
# next: “Don’t call me good!
#
# pre-previous: the Gruffalo said.
# previous: “You'll    taste good on a slice of bread!”
# current: Good?” said the mouse.
# next: “Don’t call me good!
#
# pre-previous: I'm    the scariest creature in this wood.
# previous: Just walk behind me and soon you’ll see, Everyone is    afraid of me."
# current: All right, said the Gruffalo, bursting w ith laughter.
# next: “You go ahead and I’ll follow after. "
#
# pre-previous: All right, said the Gruffalo, bursting w ith laughter.
# previous: “You go ahead and I’ll follow after. "
# current: They walked and walked till the Gruffalo said, “I hear    a hiss in the leaves ahead. ’
# next: "It’s Snake,” said the mouse.
#
# pre-previous: “You go ahead and I’ll follow after. "
# previous: They walked and walked till the Gruffalo said, “I hear    a hiss in the leaves ahead. ’
# current: "It’s Snake,” said the mouse.
# next: “Why, Snake, hello!”
#
# pre-previous: Snake    took one look at the Gruffalo.
# previous: “Oh crumbs!”
# current: he said, “Goodbye, little mouse" And off he    slid to his logpile house.
# next: “You see?" said the mouse.
#
# pre-previous: “Oh crumbs!”
# previous: he said, “Goodbye, little mouse" And off he    slid to his logpile house.
# current: “You see?" said the mouse.
# next: “I told you so.”
#
# pre-previous: “I told you so.”
# previous: “Amazing!”
# current: said the Gruffalo.
# next: They waited some more till the Gruffalo said, “I hear    a hoot in the trees ahead. ”
#
# pre-previous: “Amazing!”
# previous: said the Gruffalo.
# current: They waited some more till the Gruffalo said, “I hear    a hoot in the trees ahead. ”
# next: “It’s Owl," said the mouse.
#
# pre-previous: said the Gruffalo.
# previous: They waited some more till the Gruffalo said, “I hear    a hoot in the trees ahead. ”
# current: “It’s Owl," said the mouse.
# next: “Why, Owl, hello!”
#
# pre-previous: Owl    took one look at the Gruffalo.
# previous: Oh dear!"
# current: he said, “Goodbye, little mouse"
# next: And off he    flew to his treetop house.
#
# pre-previous: he said, “Goodbye, little mouse"
# previous: And off he    flew to his treetop house.
# current: “You see?” said the mouse.
# next: “I told you so.”
#
# pre-previous: “I told you so.”
# previous: “Astounding!”
# current: said the Gruffalo.
# next: They walked some more till the Gruffalo said, “I can    hear feet on the path ahead.
#
# pre-previous: “Astounding!”
# previous: said the Gruffalo.
# current: They walked some more till the Gruffalo said, “I can    hear feet on the path ahead.
# next: “It’s Fox,” said the mouse.
#
# pre-previous: said the Gruffalo.
# previous: They walked some more till the Gruffalo said, “I can    hear feet on the path ahead.
# current: “It’s Fox,” said the mouse.
# next: “Why, Fox, hello!”
#
# pre-previous: one look at the Gruffalo.
# previous: “Oh help!”
# current: he said, “Goodbye, little mouse,” And    off he ran to his underground house.
# next: “Well, Gruffalo, said the mouse.
#
# pre-previous: “Oh help!”
# previous: he said, “Goodbye, little mouse,” And    off he ran to his underground house.
# current: “Well, Gruffalo, said the mouse.
# next: “You see?
#
# pre-previous: “Oh help!”
# previous: he said, “Goodbye, little mouse,” And    off he ran to his underground house.
# current: “Well, Gruffalo, said the mouse.
# next: “You see?
#
# pre-previous: My favourite food is — gruffalo crumble!"
# previous: “Gruffalo crumble!”
# current: the Gruffalo said, And quick as the wind he    turned and fled.
# next: All. was quiet in the deep dark wood?- .; ' The    mouse found a nut and the nut was good.
#
# pre-previous: “SNORE,” went Mrs  Bear, “SNORE, SNORE, SNORE.”
# previous: “Oh NO!”
# current: said Mr Bear, “I can’t stand THIS.”
# next: So he got up  and went to sleep in Baby Bear’s room.
#
# pre-previous: went Baby Bear, “NYAAOW!
# previous: NYAAOW!”
# current: “Oh NO!” said Mr Bear, “I can’t stand THIS.”
# next: So he got up and went to sleep in the living  room.
#
# pre-previous: CUCKOO!
# previous: CUCKOO!
# current: “Oh NO!” said Mr Bear, “I can’t stand THIS!”
# next: So he went off to sleep in the kitchen.
#
# pre-previous: went the leaky kitchen tap.
# previous: HMMMMMMMMMMM.. went the refrigerator.
# current: “Oh NO,” said Mr Bear,  “I can’t stand THIS.”
# next: So he got up  and went to sleep in the garden.
#
# pre-previous: “MIAAAOW!”
# previous: sang the cats on the wall.
# current: “Oh NO!” said Mr Bear, “I can’t stand  THIS.”
# next: So he went off to sleep in the car.
#
# pre-previous: SHINE,  SHINE . . .
# previous: went the sun.
# current: “Oh NO!” said Mr  Bear, “I can’t stand THIS.”
# next: So he got up and went back into the house.
#
# pre-previous: In the house, Baby Bear was fast asleep, and Mrs  Bear had turned over and wasn’t snoring any  more.
# previous: Mr Bear got into bed and closed his eyes.
# current: “Peace at last,” he said to himself.
# next: BRRRRRRRRRRRRRRR!
#
# pre-previous: went the alarm clock,  BRRRRRR!
# previous: Mrs Bear sat up and rubbed her eyes.
# current: “Good morning, dear,” she said.
# next: “Did you sleep well?”
#
# pre-previous: “Did you sleep well?”
# previous: “Not VERY well, dear,” yawned  Mr Bear.
# current: “Never mind,” said Mrs Bear.
# next: “I’ll bring you a nice cup of tea.”
#
# pre-previous: They nibbled EVERYTHING!
# previous:  Someone or something had been  nibbling a hole in Kipper’s toybox.
# current: ‘I hope my toys are safe,’ said  Kipper.
# next: He emptied them out and  counted them.
#
# pre-previous: ‘One, two, three, four, five,  six, SEVEN!
# previous: That’s wrong!’
# current: he said.
# next: “There should only be six!”
#
# pre-previous: “Big Owl one, Hippopotamus two, Sock Thing  three, Slipper four, Rabbit five, Mr Snake six.
# previous: “That’s better!”
# current: he said.
# next: Kipper put his toys back in the toybox.
#
# pre-previous: ‘One, two, three, four, five, six, seven, EIGHT  NOSES!
# previous: That’s two too many noses!’
# current: said Kipper.
# next: Kipper grabbed Big Owl and threw  him out of the toybox.
#
# pre-previous: Kipper grabbed Big Owl and threw  him out of the toybox.
# previous: ‘ONE!’
# current: he said crossly.
# next: Out went Hippopotamus, ‘TWO!’
#
# pre-previous: Kipper was upset Next to Rabbit,  Sock Thing was his favourite.
# previous: Now he was gone.
# current: ‘I won’t lose any more of you,’ said  Kipper.
# next: He picked up the rest of his toys  and put them in his basket.
#
# pre-previous: Then a little tail appeared.
# previous: A little pink tail.
# current: And  a  little  voice  said,  ‘Don’t  hurt him!’
# next: So it was YOU!
#
# pre-previous: So it was YOU!
# previous: You have been making the hole in  my toybox!’
# current: said Kipper.
# next: It was true.
#
# pre-previous: It was true.
# previous: The mice had been nibbling pieces  of Kipper’s toybox to make their nest
# current: You must promise not to nibble it again,’ said  Kipper.
# next: ‘We promise,’ said the mice.
#
# pre-previous: The mice had been nibbling pieces  of Kipper’s toybox to make their nest
# previous: You must promise not to nibble it again,’ said  Kipper.
# current: ‘We promise,’ said the mice.
# next: M n W
#
# pre-previous: but it was worth it.
# previous: Apatosaurus saw an animal just like Triceratops.
# current: “That’s a    rhinoceros,” said Hany.
# next: “Triceratops has got more horns.”
#
# pre-previous: “Triceratops has got more horns.”
# previous: Mum liked the giraffes best and Nan-    liked the zebras.
# current: The monkeys were funny but the    man said not to feed them.
# next: Sam asked him if they had pandas but the man said    no, they were endangered animals.
#
# pre-previous: Mum liked the giraffes best and Nan-    liked the zebras.
# previous: The monkeys were funny but the    man said not to feed them.
# current: Sam asked him if they had pandas but the man said    no, they were endangered animals.
# next: Harry wanted to know what endangered meant;   Sam said he was too little to understand.
#
# pre-previous: The monkeys were funny but the    man said not to feed them.
# previous: Sam asked him if they had pandas but the man said    no, they were endangered animals.
# current: Harry wanted to know what endangered meant;   Sam said he was too little to understand.
# next: Nan helped.
#
# pre-previous: People kept    hunting them so there were only a few left in the whole world.
# previous: Harry really wanted to help but he had no money.
# current: “I  want to save some animals,” he said.
# next: “What can I do, Mum?”
#
# pre-previous: “I  want to save some animals,” he said.
# previous: “What can I do, Mum?”
# current: Sam said, “Tuh!
# next: What a waste of time!”
#
# pre-previous: Sam said, “Tuh!
# previous: What a waste of time!”
# current: She said he was miles too small to make any difference.
# next: That’s why Harry made her do a smudge with her    lipstick.
#
# pre-previous: Mum took Harry off to settle down.
# previous: Then they looked on the    Internet and found lots of endangered animals.
# current: Mum said why not do a poster?
# next: Harry could put it up  in his window.
#
# pre-previous: He got out his drawing stuff  straight away.
# previous: Trouble was, it was hard to know which    animal to save first.
# current: The dinosaurs said, “Raaaah!
# next: We want to save some BIG animals!1
#
# pre-previous: Tyrannosaurus did a polar bear.
# previous: Pterodactyl asked Harry to help him do a gorilla.
# current: “Wait till I’ve finished my blue whale,” said Harry.
# next: “Blue whales are bigger than trains, bigger than    dinosaurs, bigger than thirty-two elephants!”
#
# pre-previous: Stegosaurus did an army tank.
# previous: “Army tanks don’t need saving!”
# current: said Triceratops.
# next: “Do a tree frog instead.”
#
# pre-previous: said Triceratops.
# previous: “Do a tree frog instead.”
# current: Mum said the drawings were excellent.
# next: She helped put the words on.
#
# pre-previous: She helped put the words on.
# previous: LEVS SAVE THESE ENDANGERED ANIMALS!
# current: Nan said, “Why not talk to Mr Bopsom?
# next: He might put up a poster in his shop window!
#
# pre-previous: Mr Bopsom loved the pictures but he thought they might be a    bit too small for a poster.
# previous: He asked Harry if he could draw them bigger.
# current: Harry said no, sorry, his pictures always came out small.
# next: That’s a shame,” said Mr Bopsom.
#
# pre-previous: He asked Harry if he could draw them bigger.
# previous: Harry said no, sorry, his pictures always came out small.
# current: That’s a shame,” said Mr Bopsom.
# next: “Because saving animals is    important!”
#
# pre-previous: The very next day, Mr Bopsom was on the phone. ....
# previous: “I’ve had an idea!”
# current: he said.
# next: “Can you do me lots more    pictures?”
#
# pre-previous: When Harry went into the shop two weeks later he was    amazed!
# previous: Mr Bopsom had made all the drawings into cards.
# current: He said that every time somebody bought a card, some of    the money went to save endangered animals.
# next: Everybody loved them.
#
# pre-previous: He said that every time somebody bought a card, some of    the money went to save endangered animals.
# previous: Everybody loved them.
# current: They said, “Marvellous!”
# next: “What a brilliant idea!”
#
# pre-previous: The lady from the paper came and was very impressed.
# previous: “What a  wonderful thing you’ve done!”
# current: she said.
# next: “Raahh!” said Apatosaurus.
#
# pre-previous: “What a  wonderful thing you’ve done!”
# previous: she said.
# current: “Raahh!” said Apatosaurus.
# next: “Save the strawberry poison arrow frog!”
#
# pre-previous: “What a  wonderful thing you’ve done!”
# previous: she said.
# current: “Raahh!” said Apatosaurus.
# next: “Save the strawberry poison arrow frog!”
#
# pre-previous: “Raahh!” said Apatosaurus.
# previous: “Save the strawberry poison arrow frog!”
# current: “Raahh!” said Pterodactyl.
# next: “Save the teeny blue tongued skink!”
#
# pre-previous: “Raahh!” said Apatosaurus.
# previous: “Save the strawberry poison arrow frog!”
# current: “Raahh!” said Pterodactyl.
# next: “Save the teeny blue tongued skink!”
#
# pre-previous: “Raahh!” said Pterodactyl.
# previous: “Save the teeny blue tongued skink!”
# current: And Harry said, “Quite right, my dinosaurs!
# next: Because even    if you are as tiny as a tick on the tail of a green turtle, you can    still do something that makes a BIG difference.
#
# pre-previous: And he ended up in a hospital bed
# previous: In a faraway part of town.
# current: “Goodbye,” McTat said.
# next: “I must get back to Fred.”
#
# pre-previous: and on.
# previous: A week later, Sock took a stroll round the block And found her new    friend looking thin.
# current: “He’s gone off and left me!’' said Tabby McTat.
# next: Then Sock said, “My people, Prunella and Pat, Would gladly find    room for a fine tabby cat.”
#
# pre-previous: A week later, Sock took a stroll round the block And found her new    friend looking thin.
# previous: “He’s gone off and left me!’' said Tabby McTat.
# current: Then Sock said, “My people, Prunella and Pat, Would gladly find    room for a fine tabby cat.”
# next: ' She was right and they took McTat in.'
#
# pre-previous: But he dreamed of his friend    with the old checked hat
# previous: And always woke up with a meW-
# current: And often he said, “What’s happened to Fred?”
# next: And his paws  took him hack to the square. '
#
# pre-previous: And he pulled out this… and he pulled out that….And people threw    coins in the tall black hat,
# previous: But the busker was never there.
# current: One morning Sock said, “Look under the bed And see the    three kittens I’ve had!”
# next: And Soames looked like this, and Susan like that,
#
# pre-previous: •But nohody wanted poor Samuel Sprat.
# previous: •
# current: They all    said, “His voice is too loud.”
# next: Now Tabby McTat was a home-loving cat.
#
# pre-previous: And one day be called for his wife and his son   And be told them,
# previous: “There’ s something that has to be done.
# current: I must go and find him,” he said.
# next: So up and down . . .
#
# pre-previous: Then out from a shadow sprang Samuel Sprat.
# previous: “Oh please let    ME be the busker’s cat!"
# current: He said with his deafening mew.
# next: o, C
# pre-previous: She had to study the Romans for homework.
# previous: “What are Romans?” asked Harry.
# current: Sam said they were our ancestors, but he was too young to    understand.
# next: Harry wanted to take the dinosaurs to see them.
#
# pre-previous: Sam said they were our ancestors, but he was too young to    understand.
# previous: Harry wanted to take the dinosaurs to see them.
# current: Sam said, “No way!”
# next: She said Harry would just get bored and silly.
#
# pre-previous: Harry wanted to take the dinosaurs to see them.
# previous: Sam said, “No way!”
# current: She said Harry would just get bored and silly.
# next: That    was why Sam’s homework got smudged
#
# pre-previous: That    was why Sam’s homework got smudged
# previous: Mum made them both settle down.
# current: She said a    museum would be a fine outing for everybody.
# next: “I’d love to go,” said Nan.
#
# pre-previous: Mum made them both settle down.
# previous: She said a    museum would be a fine outing for everybody.
# current: “I’d love to go,” said Nan.
# next: The museum was bigger than a hospital.
#
# pre-previous: “Are these ancestors?”
# previous: asked Harry.
# current: Mum said yes, everybody in the world came from cavemen.
# next: They lit    fires and did hunting.
#
# pre-previous: “Are Egyptians ancestors?”
# previous: asked Harry.
# current: “Yes, but not the right ones,” said Sam.
# next: “We want the Romans.
#
# pre-previous: But what a lot of old pots, broken ones too!
# previous: Sam started doing drawing.
# current: “We’ve seen the Romans now,” said Harry.
# next: “I’m hungry!
#
# pre-previous: “Raaah!
# previous: Anchisaurus pinched me!”
# current: said Stegosaurus.
# next: “He’s taking up all the room!”
#
# pre-previous: said Stegosaurus.
# previous: “He’s taking up all the room!”
# current: said Anchisaurus.
# next: “Behave!”
#
# pre-previous: said Anchisaurus.
# previous: “Behave!”
# current: said Harry in a loud voice.
# next: “Look, Harry is being silly!”
#
# pre-previous: groaned Sam.
# previous: “I knew it!
# current: “I think the dinosaurs need a run about,” said Harry.
# next: Mum said better    not.
#
# pre-previous: “I knew it!
# previous: “I think the dinosaurs need a run about,” said Harry.
# current: Mum said better    not.
# next: They might get lost.
#
# pre-previous: Mum said better    not.
# previous: They might get lost.
# current: “Come on, let’s get something to eat,” she said.
# next: “Afterwards we’ll    come back here, so Sam can finish her studies.”
#
# pre-previous: Nan and Harry and the dinosaurs    waited at a table while Mum and Sam went to queue up.
# previous: “Look, I’m a caveman!
# current: Raaah!” said Triceratops.
# next: “Look, I’m a Roman!
#
# pre-previous: Nan and Harry and the dinosaurs    waited at a table while Mum and Sam went to queue up.
# previous: “Look, I’m a caveman!
# current: Raaah!” said Triceratops.
# next: “Look, I’m a Roman!
#
# pre-previous: Raaah!” said Triceratops.
# previous: “Look, I’m a Roman!
# current: Raaah!” said Pterodactyl.
# next: “Look, I’m a mummy!
#
# pre-previous: Raaah!” said Triceratops.
# previous: “Look, I’m a Roman!
# current: Raaah!” said Pterodactyl.
# next: “Look, I’m a mummy!
#
# pre-previous: Raaah!” said Pterodactyl.
# previous: “Look, I’m a mummy!
# current: Raaah!” said Tyrannosaurus.
# next: After lunch, everyone felt a lot better and they set off back    to the Romans.
#
# pre-previous: Raaah!” said Pterodactyl.
# previous: “Look, I’m a mummy!
# current: Raaah!” said Tyrannosaurus.
# next: After lunch, everyone felt a lot better and they set off back    to the Romans.
#
# pre-previous: After lunch, everyone felt a lot better and they set off back    to the Romans.
# previous: But it wasn't long before Anchisaurus got bored.
# current: “I’m bored too!” said Tyrannosaurus. ‘
# next: Never mind,” said Harry, “it’s your turn to do studying.
#
# pre-previous: But it wasn't long before Anchisaurus got bored.
# previous: “I’m bored too!” said Tyrannosaurus. ‘
# current: Never mind,” said Harry, “it’s your turn to do studying.
# next: Pay attention, my dinosaurs.”
#
# pre-previous: got lost
# previous: “Oh no!
# current: Where’s Harry?” said Mum.
# next: “Quick!   Let’s find the person in charge!”
#
# pre-previous: Where’s Harry?” said Mum.
# previous: “Quick!   Let’s find the person in charge!”
# current: Sam said Harry was stupid.
# next: “I bet he’s gone off on a bus!”
#
# pre-previous: Sam said Harry was stupid.
# previous: “I bet he’s gone off on a bus!”
# current: she said.
# next: “Nonsense!”
#
# pre-previous: she said.
# previous: “Nonsense!”
# current: said Nan.
# next: “I know where   we’ll find him!”
#
# pre-previous: They followed Nan to the prehistoric Hall.
# previous: “There he is!”
# current: said Nan.
# next: “I    knew it!”
#
# pre-previous: “Boys come from cavemen and Romans and Egyptians,” he explained.
# previous: “But these are your ancestors.”
# current: So Tyrannosaurus said “Raaah!”
# next: to his ancestor.
#
# pre-previous: All except Pterodactyl, who gave his ancestor a nose-rub.
# previous: “Now, young man!”
# current: said the person in charge.
# next: “We had better look for your mum.
#
# pre-previous: “We had better look for your mum.
# previous: Could you tell me your name?”
# current: Harry said his name, address and telephone   number, no problem at all.
# next: All the people said very good, clever boy!
#
# pre-previous: Could you tell me your name?”
# previous: Harry said his name, address and telephone   number, no problem at all.
# current: All the people said very good, clever boy!
# next: Nan rushed over.
#
# pre-previous: “He’s with us!”
# previous: she called proudly.
# current: “Harry!” said Mum.
# next: “We thought we’d lost you!”
#
# pre-previous: “He’s with us!”
# previous: she called proudly.
# current: “Harry!” said Mum.
# next: “We thought we’d lost you!”
#
# pre-previous: “We thought we’d lost you!”
# previous: “I wasn’t lost!”
# current: said Harry.
# next: “1 was with    my dinosaurs.”
#
# pre-previous: and another blue one. . .’
# previous: Percy was counting balloons.
# current: “I wonder where they’re coming from,” he said to himself.
# next: “Somebody must have had a party.”
#
# pre-previous: “Somebody must have had a party.”
# previous: He put down his trowel and wiped    his hands.
# current: “Well, if nobody wants them,” he said,    “I think I’ll help myself.”
# next: Percy chased after  the balloons as  they floated past him    on the breeze.
#
# pre-previous: He could    hear a faint sound coining from a tree stump nearby.
# previous: It was not a happy    sound.
# current: “Someone’s crying,” said Percy.
# next: “Oh dear.”
#
# pre-previous: Sitting on the tree stump, and looking    very upset, was a hedgehog.
# previous: Two mice   were doing their best to comfort him.
# current: “Goodness me,” said Percy.
# next: “Whatever    is the matter?”
#
# pre-previous: “Goodness me,” said Percy.
# previous: “Whatever    is the matter?”
# current: It’s all these balloons,” said the    hedgehog.
# next: Then, in between sniffs and sobs, he explained to Percy  how he had always loved balloons.
#
# pre-previous: “It’s just not fair!”
# previous: And the hedgehog burst into tears    again.
# current: “You poor thing,” said Percy.
# next: He tried to put his arm around the    hedgehog but took it away at once.
#
# pre-previous: “You poor thing,” said Percy.
# previous: He tried to put his arm around the    hedgehog but took it away at once.
# current: “Ouch,” he said.
# next: Then Percy took one of his thick  gardening gloves out of his pocket and put it    on.
#
# pre-previous: Then Percy took one of his thick  gardening gloves out of his pocket and put it    on.
# previous: The hedgehog nestled into his hand.
# current: “I think everyone should be able to play with balloons,” said Percy.
# next: “And that includes    hedgehogs.”
#
# pre-previous: He set the hedgehog down on a workbench and then he took a tin    from a shelf.
# previous: He opened the lid.
# current: “What’s Percy doing?” said one of the    mice.
# next: “What’s in that box?”
#
# pre-previous: “What’s Percy doing?” said one of the    mice.
# previous: “What’s in that box?”
# current: “I don’t know,” said the other mouse.
# next: “I can’t see properly.”
#
# pre-previous: The mice didn’t have to wait long to find  out.
# previous: Percy picked up the hedgehog and    brought him outside.
# current: “There!” said Percy.
# next: “A good idea, even if I say so myself!
#
# pre-previous: Percy picked up the hedgehog and    brought him outside.
# previous: “There!” said Percy.
# current: “A good idea, even if I say so myself!
# next: I think those    balloons will be safe now.”
#
# pre-previous: He thought how smart he must look,    wearing his corks.
# previous: Percy caught hold of a bright yellow    balloon.
# current: “Here you are,” said Percy as he  handed it to the hedgehog.
# next: “Your very    first balloon.”
#
# pre-previous: “Your very    first balloon.”
# previous: The hedgehog took the balloon and    with a great big smile on his face, he scampered off with the balloon floating    beside him.
# current: “Another satisfied customer,” said    Percy, feeling pleased with himself.
# next: Percy turned to go back to his hut.
#
# pre-previous: But    suddenly, there came a loud BANG!
# previous: “
# current: Oops!” said Percy.
# next: “One of the corks  must have come off.
#
# pre-previous: But    suddenly, there came a loud BANG!
# previous: “
# current: Oops!” said Percy.
# next: “One of the corks  must have come off.
#
# pre-previous:    It was a bright, cold winter’s day.
# previous: Snow had fallen in the night and now everything in the park had been    turned into a guessing game.
# current: “It looks wonderful,” said Percy the    park keeper, “but it makes a lot of work.”
# next: Standing next to Percy was a rather    old and cross looking rabbit.
#
# pre-previous: “It looks wonderful,” said Percy the    park keeper, “but it makes a lot of work.”
# previous: Standing next to Percy was a rather    old and cross looking rabbit.
# current: “Well, quite so,” said the rabbit.
# next: “But now, what about these mice?
#
# pre-previous: After all, this  was no fun for an old rabbit who only  wanted to curl up and sleep through the    cold weather.
# previous: I     “Now come along
# current: , you mice,” said Percy.
# next: “You must go and play somewhere  else.
#
# pre-previous: The mice looked very disappointed.
# previous: Slowly they walked away, dragging their    toboggans behind them.
# current: The old rabbit said thank you to Percy and    then disappeared into his burrow.
# next: M. S    Percy got on with clearing the snow.
#
# pre-previous: Percy worked hard all morning.
# previous: He mopped his brow again and   looked at his work.
# current: “Very good,” he said to himself.
# next: “I think I deserve a spot of lunch.”
#
# pre-previous: “I think I deserve a spot of lunch.”
# previous: Percy reached for his bag and pulled    out a flask.
# current: “That’s funny,” he said.
# next: “I’m sure I put    the cup on the top this morning.”
#
# pre-previous: “I know, I’ll have mg yogurt first and    drink from the empty carton.”
# previous: Percy took out a strawberry  yogurt and began to    rummage through his bag. ‘
# current: That’s odd,” he said.
# next: “No spoon.
#
# pre-previous: It felt colder to Percy as he went back to    work.
# previous: He reached for his scarf and his   cap, but now they had disappeared too!
# current: “This is most peculiar,” said Percy.
# next: Then, as he gazed around looking for his  cap and scarf, Percy was amazed to see his    gloves walking off by themselves!
#
# pre-previous: “This is most peculiar,” said Percy.
# previous: Then, as he gazed around looking for his  cap and scarf, Percy was amazed to see his    gloves walking off by themselves!
# current: “I must be dreaming,” said Percy.
# next: “I’d like to be dreaming,” said a cross    voice.
#
# pre-previous: Then, as he gazed around looking for his  cap and scarf, Percy was amazed to see his    gloves walking off by themselves!
# previous: “I must be dreaming,” said Percy.
# current: “I’d like to be dreaming,” said a cross    voice.
# next: It was the old rabbit again.
#
# pre-previous: Then, as he gazed around looking for his  cap and scarf, Percy was amazed to see his    gloves walking off by themselves!
# previous: “I must be dreaming,” said Percy.
# current: “I’d like to be dreaming,” said a cross    voice.
# next: It was the old rabbit again.
#
# pre-previous: Percy followed.
# previous: “Look!”
# current: said the rabbit.
# next: Percy looked.
#
# pre-previous: “You’re not going to tell us to    stop, are you?”
# previous: Percy glanced at the old rabbit.
# current: “Well. . .no,” he said to the mice.
# next: “We just wondered if you could have a marvellous    time a little   more quietly?”
#
# pre-previous: “We’ll try!”
# previous: they squeaked loudly.
# current: “Come on,” said Percy to the rabbit.
# next: “I think I’ve got some cotton wool  in my bag.
#
# pre-previous: Harry wanted to take his dinosaurs, but they  were hiding all over the place.
# previous: He called all  their names.
# current: He said, “Get in the bucket, my Stegosaurus.”
# next: And out came Stegosaurus from under the  pillow.
#
# pre-previous: He said, “Get in the bucket, my Stegosaurus.”
# previous: And out came Stegosaurus from under the  pillow.
# current: He said, “Get in the bucket, my Triceratops.”
# next: And out came Triceratops from inside the  drawer.
#
# pre-previous: He didn’t want to go  because he had a lot of teeth.
# previous: He thought Mr Drake might do drilling on them.
# current: Harry said, “Don’t worry, because when we get there, I shall  press a magic button on my bucket, and that will make you  grow big.”
# next: In the waiting room, the nurse said, “Hello,  Harry.
#
# pre-previous: He thought Mr Drake might do drilling on them.
# previous: Harry said, “Don’t worry, because when we get there, I shall  press a magic button on my bucket, and that will make you  grow big.”
# current: In the waiting room, the nurse said, “Hello,  Harry.
# next: Are you a good boy?”
#
# pre-previous: In the waiting room, the nurse said, “Hello,  Harry.
# previous: Are you a good boy?”
# current: Harry said, “I am, but my dinosaurs bite.”
# next: Mr Drake called,  “Next please!”
#
# pre-previous: Harry wasn’t sure about the big chair.
# previous: He thought maybe that  was where Mr Drake did the drilling.
# current: “Come and have a ride in my chair,” said Mr Drake.
# next: “It goes up and down.”
#
# pre-previous: He  whispered to him not to worry, then he  pressed the magic button…
# previous: Tyrannosaurus grew VERY BIG!
# current: “Open wide,” said Mr Drake, and
# next: then  he turned around ...
#
# pre-previous: then  he turned around ...
# previous: “RAAAAHH!”
# current: said Tyrannosaurus.
# next: “Help!”
#
# pre-previous: Then Harry and his dinosaurs  all had a ride together.
# previous: They opened their mouths wide for  Mr Drake and all went, ‘RAAAAHH!’
# current: Mr Drake said, “What a lot of teeth!
# next: Will they bite me?”
#
# pre-previous: Mr Drake said, “What a lot of teeth!
# previous: Will they bite me?”
# current: Harry said, “They only bite drills.”
# next: “You are all good brushers,” said Mr Drake,  “so no drills today, only a look and a rinse.”
#
# pre-previous: Will they bite me?”
# previous: Harry said, “They only bite drills.”
# current: “You are all good brushers,” said Mr Drake,  “so no drills today, only a look and a rinse.”
# next: All the dinosaurs liked riding
#
# pre-previous: “Another bucket of mouthwash, Joan!” called Mr  Drake.
# previous: Going home, Mum let Harry choose a book from the library for  being so good.
# current: “Let’s have a shark book!” said Harry.
# next: “RAAAAHH!”
#
# pre-previous: “Let’s have a shark book!” said Harry.
# previous: “RAAAAHH!”
# current: said the dinosaurs.
# next: “Sharp teeth!
#
# pre-previous: Look what we’ve found!”
# previous: Just ahead of him, a squirrel friend and the mole were    standing over a heap of twigs.
# current: “Hello,” said Percy.
# next: “That looks like an old nest.”
#
# pre-previous: He    picked it up.
# previous: “I shouldn’t think anyone lives in it now.”
# current: “Then you’d be wrong,” said a little voice.
# next: A small feathery head stuck itself  out from beneath the twigs.
#
# pre-previous: “I live in it.
# previous: And you’re holding me upside down.”
# current: “I’m so sorry,” said Percy.
# next: He turned  the nest over.
#
# pre-previous: He turned  the nest over.
# previous: “I thought you would have    gone with your friends and relations.”
# current: “Can’t fly,” said the little bird.
# next: “I didn’t    get the hang of it.”
#
# pre-previous: This little fellow can’t fly.”
# previous: “Flying?”
# current: said the owl, as she swooped  overhead.
# next: “Nothing to it,” she hooted, as    she went into an impressive spin.
#
# pre-previous: The owl hit a pine tree.
# previous: Pine cones rained down on the  squirrel and the mole, followed by the owl in a dazed and untidy    heap.
# current: “Well,” said Percy, “I think there’s    a lesson for us all.”
# next: “Percy,” said the squirrel, “have you    got any string?”
#
# pre-previous: Pine cones rained down on the  squirrel and the mole, followed by the owl in a dazed and untidy    heap.
# previous: “Well,” said Percy, “I think there’s    a lesson for us all.”
# current: “Percy,” said the squirrel, “have you    got any string?”
# next: Percy felt in his pocket.
#
# pre-previous: “Percy,” said the squirrel, “have you    got any string?”
# previous: Percy felt in his pocket.
# current: “Here’s a piece,” he said.
# next: “Why do you want it?
#
# pre-previous: “Why do you want it?
# previous: The squirrel jumped to his feet.
# current: “Come on,” he said to the little   bird.
# next: “I’ll give you a piggy-back.”
#
# pre-previous: “He needs to get used to heights,”    explained the squirrel.
# previous: When he reached the top, the    squirrel tied the string between   two branches.
# current: “It’s a tightrope,” he said.
# next: “Follow me!”
#
# pre-previous: As Percy plodded on he saw his friend the fox  coming up the path  towards him.
# previous: The fox was on  his way home too.
# current: “Good night,” said Percy as they passed each    other.
# next: “Good night, hic-Percy,” answered   the fox.
#
# pre-previous: It was  then that he had learnt that it is not a  good idea to laugh and drink at the same    time.
# previous: He had had hiccups all afternoon.
# current: “I wonder if hic-Percy knows a good  cure for hic-cups,” the fox said to himself.
# next: “I th-hic
#
# pre-previous: “I wonder if hic-Percy knows a good  cure for hic-cups,” the fox said to himself.
# previous: “I th-hic
# current: I’ll ask him,” he said and with    that he turned and followed after Percy.
# next: When he got back to his hut, Percy    remembered that he still had one or two jobs to do.
#
# pre-previous: When he got back to his hut, Percy    remembered that he still had one or two jobs to do.
# previous: First, he watered some    plants.
# current: “I’d better get my washing in too,” said  Percy.
# next: “Then, it’s two boiled eggs for me and a    pile of toast soldiers.”
#
# pre-previous: Percy had never met a ghost before.
# previous: He felt he should introduce himself.
# current: But what should he say to a ghost?
# next: Percy listened hard.
#
# pre-previous: “Could you possibly turn me the right    way up?”
# previous: Percy helped the fox back on to his feet.
# current: “You gave me quite a shock,” said   Percy.
# next: “I gave myself one,” said the fox.
#
# pre-previous: Percy helped the fox back on to his feet.
# previous: “You gave me quite a shock,” said   Percy.
# current: “I gave myself one,” said the fox.
# next: “But it seems    to have cured my hiccups!”
#
# pre-previous:    “Can I go to the moon?”
# previous: asked Baby Bear.
# current: “No, you can’t,” said Mrs Bear.
# next: “It’s bathtime.
#
# pre-previous: out into the night.
# previous: An owl flew past.
# current: “That’s a smart rocket,” he said.
# next: “Where are you off to?”
#
# pre-previous: “That’s a smart rocket,” he said.
# previous: “Where are you off to?”
# current: “The moon,” said Baby Bear.
# next: “Would you like to  come too?”
#
# pre-previous: “The moon,” said Baby Bear.
# previous: “Would you like to  come too?”
# current: “Yes please,” said the owl.
# next: An aeroplane roared out of the clouds.
#
# pre-previous: On and on
# previous: they flew, up and up, above the clouds, past  millions of stars till at last they landed on the moon.
# current: “There’s nobody here,” said Baby Bear.
# next: “There are no trees,” said the owl.
#
# pre-previous: they flew, up and up, above the clouds, past  millions of stars till at last they landed on the moon.
# previous: “There’s nobody here,” said Baby Bear.
# current: “There are no trees,” said the owl.
# next: “It’s a bit boring,” said Baby Bear.
#
# pre-previous: “There’s nobody here,” said Baby Bear.
# previous: “There are no trees,” said the owl.
# current: “It’s a bit boring,” said Baby Bear.
# next: “Shall we have a picnic?”
#
# pre-previous: “It’s a bit boring,” said Baby Bear.
# previous: “Shall we have a picnic?”
# current: “What a good idea,” said the owl.
# next: “We’d better go,” said Baby Bear, “
#
# pre-previous: “Shall we have a picnic?”
# previous: “What a good idea,” said the owl.
# current: “We’d better go,” said Baby Bear, “
# next: My  bath must be ready by now,” Off they  went, down and down.
#
# pre-previous: My  bath must be ready by now,” Off they  went, down and down.
# previous: The owl got out  and flew away.
# current: “Goodbye,” he said.
# next: “It  was so nice to meet you.”
#
# pre-previous: she gasped as she led him away to  the bathroom.
# previous: “Why, you look as if you’ve been up the chimney.”
# current: “As a matter of fact,” said Baby Bear, “I have been up  the chimney.
# next: I found a rocket and went to  visit the moon.”
#
# pre-previous: I found a rocket and went to  visit the moon.”
# previous: Mrs Bear laughed.
# current: “You and your stories,” she said.
# next: “Whatever next?”
# pre-previous: He tried his  hardest every day to win a golden star.
# previous: All the dragons in Year One were learning how to fly.
# current: “High!” said Madam Dragon.
# next: “Way up in the sky!
#
# pre-previous: then crashed into a tree.
# previous: Just then, a little girl ca me by.
# current: “Oh, please don’t cry,” she said.
# next: “Perhaps you’d like a nice sticky  plaster for your head?”
#
# pre-previous: “Oh, please don’t cry,” she said.
# previous: “Perhaps you’d like a nice sticky  plaster for your head?”
# current: “What a good idea!” said Zog.
# next: Then up and off he  flew, His plaster  gleaming pinkly as he zigzagged through the blue.
#
# pre-previous: “Oh, please don’t cry,” she said.
# previous: “Perhaps you’d like a nice sticky  plaster for your head?”
# current: “What a good idea!” said Zog.
# next: Then up and off he  flew, His plaster  gleaming pinkly as he zigzagged through the blue.
#
# pre-previous: A year went by, and in Year Two the dragons lear ned to roar.
# previous: •
# current: “More!” said Madam Dragon.
# next: “Louder, I implore! '
#
# pre-previous: but then his throat grew hoarse.
# previous: Just then the girl came by again.
# current: She  said, “What rotten luck!
# next: Perhaps you’d like  a nice soothing peppermint to suck?”
#
# pre-previous: She  said, “What rotten luck!
# previous: Perhaps you’d like  a nice soothing peppermint to suck?”
# current: “What a good idea!” said Zog.
# next: Then up and off he flew,   And breathing fumes of peppermint he zigzagged through the blue.
#
# pre-previous: She  said, “What rotten luck!
# previous: Perhaps you’d like  a nice soothing peppermint to suck?”
# current: “What a good idea!” said Zog.
# next: Then up and off he flew,   And breathing fumes of peppermint he zigzagged through the blue.
#
# pre-previous: Then up and off he flew,   And breathing fumes of peppermint he zigzagged through the blue.
# previous: A year went by, and in Year Three the dragons learned to blow.
# current: “No!” said Madam  Dragon.
# next: “Breathe out fire, not snow!
#
# pre-previous: He twirled around in triumph ...   and his wing tip caught alight.
# previous: Just then the girl came by again.
# current: She said, “You poor old th ing.
# next: Perhaps you’d like a nice stretchy bandage for your wing?”
#
# pre-previous: She said, “You poor old th ing.
# previous: Perhaps you’d like a nice stretchy bandage for your wing?”
# current: “What a good idea!” said Zog.
# next: Then up a nd off
#
# pre-previous: She said, “You poor old th ing.
# previous: Perhaps you’d like a nice stretchy bandage for your wing?”
# current: “What a good idea!” said Zog.
# next: Then up a nd off
#
# pre-previous: All the Year Four dragons were learning —
# previous: c an you guess?
# current: “Yes!” said  Madam Dragon.
# next: “How to capture a princess!
#
# pre-previous: ‘I’ll never win a golden star!”
# previous: Just then he saw the girl.
# current: ‘Perhaps,” she said, “you’d like to capture met
# next: I’m Princess Pearl.”
#
# pre-previous: ‘Perhaps,” she said, “you’d like to capture met
# previous: I’m Princess Pearl.”
# current: “What a good idea!” said Zog.
# next: Then up and off t hey flew, The princess gripping tightly as they zigzagged  through the blue.
#
# pre-previous: ‘Perhaps,” she said, “you’d like to capture met
# previous: I’m Princess Pearl.”
# current: “What a good idea!” said Zog.
# next: Then up and off t hey flew, The princess gripping tightly as they zigzagged  through the blue.
#
# pre-previous: “What a good idea!” said Zog.
# previous: Then up and off t hey flew, The princess gripping tightly as they zigzagged  through the blue.
# current: “Ah,” said Madam Dragon.
# next: “Our first princess so far!
#
# pre-previous: She took the dragons’ temperatures,  and nursed them when they fell.
# previous: A year went by and, in Year Five, the dragons learned to fight.
# current: “Right!” said Madam Dragon.
# next: “Here comes a real live knight!”
#
# pre-previous: “Right!” said Madam Dragon.
# previous: “Here comes a real live knight!”
# current: Up spoke the knight: “ My name,” he said, “is  Gadabout the Great.
# next: I’ve come to rescue Princ ess Pearl.
#
# pre-previous: “I want to be a doc tor, and travel here and there, Listening to people’s chests and  giving them my care. ;M=, rao!-
# previous: „daimed the and took h. offh.
# current: 1 d rather wear a nice twisty stethoscope,” he said.
# next: “Perhaps, Princess, you’ll train me up?”
#
# pre-previous: “Perhaps, Princess, you’ll train me up?”
# previous: And Pearl repl ied, “Of course, But I  don’t see how the two of us could fit upon your horse.”
# current: Then Zog said, “Flying doctors!
# next: I’d love to join the crew.
#
# pre-previous: I’d love to join the crew.
# previous: If you’ll let me be your  ambulance, then I can carry you.”
# current: “Bravo!” said Madam Dragon.
# next: “An  excellent  career!”
#
# pre-previous: I’d love to join the crew.
# previous: If you’ll let me be your  ambulance, then I can carry you.”
# current: “Bravo!” said Madam Dragon.
# next: “An  excellent  career!”
#
# pre-previous: Then Madam Dragon told the horse, “I really hope you’ ll stay.
# previous: I’ll let you be my pupils’ pet, and feed you lots of hay.”
# current: “What a good idea!” said Zog.
# next: Then  up and off he flew, The Flying Doctors waving  as they zigzagged through the blue.
#
# pre-previous: Then Madam Dragon told the horse, “I really hope you’ ll stay.
# previous: I’ll let you be my pupils’ pet, and feed you lots of hay.”
# current: “What a good idea!” said Zog.
# next: Then  up and off he flew, The Flying Doctors waving  as they zigzagged through the blue.
#
# pre-previous: Mr Croc told everyone his good idea.
# previous: He told them they were going to work in teams.
# current: He  said each team was going to build a go-kart out of  the wood and the wheels.
# next: He said that when the go- karts were finished, they would race them round the  swamp.
#
# pre-previous: He told them they were going to work in teams.
# previous: He  said each team was going to build a go-kart out of  the wood and the wheels.
# current: He said that when the go- karts were finished, they would race them round the  swamp.
# next: Then Mr Croc asked who would like to drive  the go-karts.
#
# pre-previous: He  told Monkey that he was going to drive a go-kart, too.
# previous: Monkey was very excited.
# current: Mr Croc said that everyone needed to listen to the  instructions.
# next: He said it was important to listen  carefully.
#
# pre-previous: Monkey was very excited.
# previous: Mr Croc said that everyone needed to listen to the  instructions.
# current: He said it was important to listen  carefully.
# next: He said everyone had to work as a team.
#
# pre-previous: Mr Croc said that everyone needed to listen to the  instructions.
# previous: He said it was important to listen  carefully.
# current: He said everyone had to work as a team.
# next: They had to work together to build the go-karts.
#
# pre-previous: He said everyone had to work as a team.
# previous: They had to work together to build the go-karts.
# current: He  said they had to check they were safe to race, too.
# next: Everyone listened carefully.
#
# pre-previous: Little Lion had to fix the steering  wheel.
# previous: Monkey had to check the wheels and the steering  wheel.
# current: Mr Croc said it was important to check  them carefully to make sure the go-kart was safe  to race.
# next: But Monkey did not listen.
#
# pre-previous: Everyone was  excited.
# previous: Monkey and Elephant lined up at the start.
# current: Mr  Croc  said  they  needed  to  listen  to  the  instructions.
# next: He  told  them  not  to go  too  fast  round the corner of the swamp.
#
# pre-previous: Mr  Croc was cross.
# previous: “Monkey needs to listen!"
# current: everyone said.
# next: Monkey was sorry that he had not listened.
#
# pre-previous: He asked Mr  Croc if everyone could help mend Monkey's go- kart.
# previous: He asked if they could race the go-karts  again when it was mended.
# current: Mr Croc said it was a  very good idea.
# next: Everyone helped to mend Monkey's go-kart.
#
# pre-previous: When it was cold he wrapped him    up in a bit of blanket.
# previous: Now and again Dave’s
# current: Mum said that Dogger was getting much too dirty.
# next: She showed Dave how to'  wash him in a bowl of soapy water.
#
# pre-previous: Next to the school gate  where the mums waited was a playing-field.
# previous: Some  men with ladders were putting up coloured flags.
# current: Mum said that there was going to be a Summer Fair  to get money to buy things for the school.
# next: Dave  pushed Dogger up against the railings to show him    what was going on.
#
# pre-previous: At tea-time Dave was rather quiet.
# previous: In the bath he was even quieter.
# current: At bed-time he said:
# next: “I want Dogger.”
#
# pre-previous: Dave began to    cry.
# previous: Bella ran after her and  tried to explain that  Dogger really belonged to  Dave, and could they    please buy him back?
# current: But the little girl said:   “No.”
# next: She said that she had  bought Dogger with her  own money
#
# pre-previous: Bella ran after her and  tried to explain that  Dogger really belonged to  Dave, and could they    please buy him back?
# previous: But the little girl said:   “No.”
# current: She said that she had  bought Dogger with her  own money
# next: and she  wanted him.
#
# pre-previous: Then Dave smiled too.
# previous: He hugged Dogger and he hugged Bella round the    waist.
# current: “Thank you, Bella,” he said.
# next: Thai night Dave had Dogger in bed beside him.
#
# pre-previous: “Shall you miss that big Teddy?”
# previous: Dave asked her.
# current: “No,” said Bella, “I didn’t like him much really.
# next: He was too big and his eyes were too staring.
#
# pre-previous: ...
# previous: kind, clever Sir Charlie Stinky Socks gave that old dragon a long cooooool drink.
# current: "Now you've stopped coughing," said the knight to the long, green dragon, "tell me what's    at the top of this tower."
# next: The dragon looked up.
#
# pre-previous: It's not a dragon's place to ask, you know -  just - to do."
# previous: “Then why don’t we find out?”
# current: said Sir Charlie with a grin.
# next: The wily witch took one last look at her watch, jumped for  joy and flew off on her broom as Charlie pushed open the    big wooden door.
#
# pre-previous: And it’s in the the middle of a deep,  dark forests, where wiggly wood wait in the grass to tickle  your toes, hungry beasties moan and monstrous trees groan…
# previous: so nobody ever comes!”
# current: "Oh, yes they do,"    said Sir Charlie, as he flung open the door.
# next: “Behold Sir Stinky Socks and his friends!”
#
# pre-previous: "
# previous: Many happy returns of the day!"
# current: he said.
# next: And everyone cheered hooray, hooray, hooray,  because that's what people do at the end of a really  big adventure.
# pre-previous: The sea    is deep and the world is wide!
# previous: How I long to sail!”
# current: Said the tiny snail.
# next: These are the other snails in the flock,  Who all stuck tight to the smooth black rock  And said to the snail with the itchy foot,  “Be quiet!
#
# pre-previous: The tiny snail
# previous: On the tail of the whale.
# ...
#
# pre-previous: He told Miss Bird his good idea.
# previous: She  said it was a very good one.
# current: Hippo said sorry to everyone-
# next: He said sorry to Mrs Croc.
#
# pre-previous: She  said it was a very good one.
# previous: Hippo said sorry to everyone-
# current: He said sorry to Mrs Croc.
# next: He said sorry to Hattie the cat, too!
#
# pre-previous: Hippo said sorry to everyone-
# previous: He said sorry to Mrs Croc.
# current: He said sorry to Hattie the cat, too!
# next: Then Hippo asked Mrs Croc if she would help him  to bake a new chocolate cake for everyone.
#
# pre-previous: It tasted  wonderful!
# previous: Hippo was pleased.
# current: Hippo said he was glad he had owned up and  put things right.
# next: Then Mrs Croc asked him if  he would like some cake.
#
# pre-previous: Hippo said he was glad he had owned up and  put things right.
# previous: Then Mrs Croc asked him if  he would like some cake.
# current: Hippo said he did not want any.
# next: He said he did  not want any chocolate cake ever again!
#
# pre-previous: Then Mrs Croc asked him if  he would like some cake.
# previous: Hippo said he did not want any.
# current: He said he did  not want any chocolate cake ever again!
# next: Everyone laughed.
#
# pre-previous:  It was Monday morning
# previous: and it was Leopard's first  day at Jungle School.
# current: Miss Bird said he could sit  with Monkey, Little Lion and Giraffe.
# next: She said  Monkey, Little Lion and Giraffe could be Leopard's  friends and help him to feel welcome.
#
# pre-previous: and it was Leopard's first  day at Jungle School.
# previous: Miss Bird said he could sit  with Monkey, Little Lion and Giraffe.
# current: She said  Monkey, Little Lion and Giraffe could be Leopard's  friends and help him to feel welcome.
# next: But Giraffe was cross.
#
# pre-previous: He did not Want to make Leopard feel  welcome.
# previous: At playtime, Monkey, Little Lion and Giraffe played  football.
# current: Monkey said Leopard could play, too.
# next: But  Giraffe got cross.
#
# pre-previous: Monkey said Leopard could play, too.
# previous: But  Giraffe got cross.
# current: He said Leopard could not  play.
# next: He told Leopard to go away.
#
# pre-previous: Leopard was  sad.
# previous: He did not like being left out.
# current: Little Lion said  Giraffe was being very unkind.
# next: On Tuesday, Leopard came to school early.
#
# pre-previous: On Tuesday, Leopard came to school early.
# previous: He  was very excited.
# current: He said it was his birthday on  Saturday.
# next: He said everyone could come to his  party.
#
# pre-previous: He  was very excited.
# previous: He said it was his birthday on  Saturday.
# current: He said everyone could come to his  party.
# next: Leopard gave out lots of invitations.
#
# pre-previous: He did not like being left out.
# previous: Leopard told everyone about his party.
# current: He said it  would be good fun.
# next: He said everyone would get  party hats.
#
# pre-previous: Leopard told everyone about his party.
# previous: He said it  would be good fun.
# current: He said everyone would get  party hats.
# next: He said there would be lots of games to  play.
#
# pre-previous: He said it  would be good fun.
# previous: He said everyone would get  party hats.
# current: He said there would be lots of games to  play.
# next: He said there would be cakes, buns and jellies  to eat.
#
# pre-previous: He said everyone would get  party hats.
# previous: He said there would be lots of games to  play.
# current: He said there would be cakes, buns and jellies  to eat.
# next: He said there would be races, too.
#
# pre-previous: He said there would be lots of games to  play.
# previous: He said there would be cakes, buns and jellies  to eat.
# current: He said there would be races, too.
# next: Giraffe felt sad.
#
# pre-previous: Giraffe felt sad.
# previous: He wished he could go to Leopard's  party.
# current: But Monkey said that Giraffe had been unkind  to Leopard.
# next: Little Lion said if he had been  kinder he might not have been left out.
#
# pre-previous: He wished he could go to Leopard's  party.
# previous: But Monkey said that Giraffe had been unkind  to Leopard.
# current: Little Lion said if he had been  kinder he might not have been left out.
# next: That afternoon, Miss Bird said they had to work with  a partner to make model boats.
#
# pre-previous: But Monkey said that Giraffe had been unkind  to Leopard.
# previous: Little Lion said if he had been  kinder he might not have been left out.
# current: That afternoon, Miss Bird said they had to work with  a partner to make model boats.
# next: She said everyone  had to test the boats at the end to make sure they  floated.
#
# pre-previous: Little Lion said if he had been  kinder he might not have been left out.
# previous: That afternoon, Miss Bird said they had to work with  a partner to make model boats.
# current: She said everyone  had to test the boats at the end to make sure they  floated.
# next: She said Giraffe and Leopard had to work  together.
#
# pre-previous: That afternoon, Miss Bird said they had to work with  a partner to make model boats.
# previous: She said everyone  had to test the boats at the end to make sure they  floated.
# current: She said Giraffe and Leopard had to work  together.
# next: But Giraffe was cross.
#
# pre-previous: He told Miss Bird
# previous: he did not want to work with Leopard.
# current: He said  Leopard was not his friend.
# next: But Miss Bird did not  listen.
#
# pre-previous: But they helped each other.
# previous: Giraffe and Leopard were pleased when the boat  floated.
# current: Miss Bird said they had worked well  together.
# next: 17
#
# pre-previous: At playtime, Giraffe asked Leopard if he would like  to play football with him, Monkey and Little Lion.
# previous: They all played together.
# current: Giraffe  said  Leopard  was  a  good  player.
# next: Giraffe said he was sorry for being unkind.
#
# pre-previous: They all played together.
# previous: Giraffe  said  Leopard  was  a  good  player.
# current: Giraffe said he was sorry for being unkind.
# next: He  said he wanted to be friends.
#
# pre-previous: Giraffe  said  Leopard  was  a  good  player.
# previous: Giraffe said he was sorry for being unkind.
# current: He  said he wanted to be friends.
# next: The next day, Leopard had a surprise for  Giraffe.
#
# pre-previous: Everyone ate it  all up.
# previous: It was delicious!
# current: Then Leopard's dad said it was time to start the  races.
# next: There was a running race and a hopping  race.
#
# pre-previous: At last it was time to go home.
# previous: Everyone  thanked Leopard for a lovely party.
# current: "Let's play  together tomorrow," said Leopard.
# next: "Playing  together is fun."
#
# pre-previous: "Let's play  together tomorrow," said Leopard.
# previous: "Playing  together is fun."
# current: "Yes," said Giraffe, "but let's all  play together tomorrow.
# next: Then no one will be left  out at all.
#
# pre-previous: But one boy called Danny, a greedy young chap,  The greediest chap on the planet in fact, Was lying  awake on his mountain of toys,  Which stood even taller than most girls and boys.
# previous: But that wasn't enough, Danny still wanted more,  He wanted much more than his toy box could store.
# current: So big Santy C said, "I'll leave him a present,
# next: But this year his present might just be unpleasant?
#
# pre-previous: There, under the tree, were gifts big and small.
# previous: And a Gimungus  egg placed in front of them all.  "An egg?!"
# current: Danny said.
# next: “Santa brought me an egg?!
#
# pre-previous: The dinosaur finally gave a huge push  And pooped Danny's parents in one massive  Whooooooosh!
# previous: Last, but not least, and never forgotten, Granny  plopped out of the dinosaur's bottom.
# current: “Merry Christmas,’ said Dan to his whole family
# next: As they washed off the presents and put up the tree.
#
# pre-previous: It was a  horrid feeling.
# previous: On Friday, Miss Bird had some exciting news.
# current: She  said it was the Big Day
# next: Out in two weeks' time.
#
# pre-previous: She  said it was the Big Day
# previous: Out in two weeks' time.
# current: She  said this year they were all going to Jungle Land and  Mr Croc was going to take them in the school minibus.
# next: Everyone clapped and cheered.
#
# pre-previous: Lion's in a flap!
# previous: "
# current: everyone said.
# next: Miss Bird took Lion outside to calm down.
#
# pre-previous: Lion felt a lot better.
# previous: Then Miss Bird told Lion that everyone gets worried  sometimes.
# current: She said Lion could always talk about his  worries with his friends.
# next: Lion said that Monkey and  Hippo were his best friends.
#
# pre-previous: Then Miss Bird told Lion that everyone gets worried  sometimes.
# previous: She said Lion could always talk about his  worries with his friends.
# current: Lion said that Monkey and  Hippo were his best friends.
# next: Miss Bird said they  would be very good friends to talk to if he felt worried  again.
#
# pre-previous: She said Lion could always talk about his  worries with his friends.
# previous: Lion said that Monkey and  Hippo were his best friends.
# current: Miss Bird said they  would be very good friends to talk to if he felt worried  again.
# next: Lion felt much, much better.
#
# pre-previous: He went on  the Roaring Rocket instead and that was even  more fun!
# previous: Then Miss Bird looked at her watch.
# current: She said there  was just enough time for everyone to go on the big  drop.
# next: The Big Drop was the highest, fastest and  scariest ride in Jungle Land.
#
# pre-previous: He felt a bit better.
# previous: He  told Monkey and Hippo his worries.
# current: Monkey said the  ride could not be too high, too fast or too scary  because everyone was having lots of fun on it.
# next: Then  Hippo said that they would all sit together so that  Lion felt nice and safe.
#
# pre-previous: He  told Monkey and Hippo his worries.
# previous: Monkey said the  ride could not be too high, too fast or too scary  because everyone was having lots of fun on it.
# current: Then  Hippo said that they would all sit together so that  Lion felt nice and safe.
# next: Lion felt much better.
#
# pre-previous: “Neigh!
# previous: Neigh!”
# current: said the horse.
# next: “Want to go for a ride?”
#
# pre-previous: The spider didn’t answer.
# previous: She was very busy spinning her web.
# current: n “Moo! Moo!” said the cow.
# next: “Want to eat some grass?”
#
# pre-previous: The spider didn’t answer.
# previous: She was very busy spinning her web.
# current: n “Moo! Moo!” said the cow.
# next: “Want to eat some grass?”
#
# pre-previous: The spider didn’t answer.
# previous: She was very busy spinning her web.
# current: “Maa! Maa!” said the goat.
# next: “Want to jump on the rocks?”
#
# pre-previous: “Careful, Santa!” quacked the ducks.
# previous: “You nearly squashed us.”
# current: “How awful,” said Santa as he gathered    up the presents.
# next: “Sorry about that.
#
# pre-previous: he cried.
# previous: “Careful, Santa!” called the squirrel.
# current: “I am trying to be careful,” said Santa, as he struggled to    get free.
# next: Very, very slowly, Santa climbed back down again,    dropping some presents as he went.
#
# pre-previous: warned Santa’s cat.
# previous: “Eeek! I can’t stop!”
# current: said Santa, as he zoomed towards the    snowman . . .
# next: “Sorry, Snowman, I didn’t mean to bump you,” Santa said, as he  dusted himself down and popped the last of the presents into his    sack.
#
# pre-previous: “Eeek! I can’t stop!”
# previous: said Santa, as he zoomed towards the    snowman . . .
# current: “Sorry, Snowman, I didn’t mean to bump you,” Santa said, as he  dusted himself down and popped the last of the presents into his    sack.
# next: “That’s it!”
#
# pre-previous: Quickly,  Santa took off his jacket and spread    it out on the ground.
# previous: Everyone gathered round and held    the coat like a trampoline.
# current: “Hold on tight, everyone, and    don’t let go!” said Santa.
# next: “Ready, Mouse?
#
# pre-previous: their Owl Mother was  GONE.
# previous: “Where’s Mummy?” asked Sarah.
# current: “Oh my  goodness! said Percy.
# next: “I want my mummy!”
#
# pre-previous: their Owl Mother was  GONE.
# previous: “Where’s Mummy?” asked Sarah.
# current: “Oh my  goodness! said Percy.
# next: “I want my mummy!”
#
# pre-previous: “Oh my  goodness! said Percy.
# previous: “I want my mummy!”
# current: said  Bill.
# next: The baby owls thought  (all owls think a lot) -
#
# pre-previous: said  Bill.
# previous: The baby owls thought  (all owls think a lot) -
# current: “I think she’s gone hunting, said Sarah.
# next: “To get us our food! said Percy.
#
# pre-previous: The baby owls thought  (all owls think a lot) -
# previous: “I think she’s gone hunting, said Sarah.
# current: “To get us our food! said Percy.
# next: “I want my mummy! said Bill.
#
# pre-previous: “I think she’s gone hunting, said Sarah.
# previous: “To get us our food! said Percy.
# current: “I want my mummy! said Bill.
# next: > -
#
# pre-previous: and they sat on the tree and  waited.
# previous: A big branch for Sarah, a small branch for Percy,  and an old bit of ivy for Bill.
# current: “She’ll be back,” said  Sarah.
# next: “Back soon!” said Percy.
#
# pre-previous: A big branch for Sarah, a small branch for Percy,  and an old bit of ivy for Bill.
# previous: “She’ll be back,” said  Sarah.
# current: “Back soon!” said Percy.
# next: “I want my  mummy!” said Bill.
#
# pre-previous: “She’ll be back,” said  Sarah.
# previous: “Back soon!” said Percy.
# current: “I want my  mummy!” said Bill.
# next: 9
#
# pre-previous: ~  ‘ It was dark in the wood and they had to be brave,  for things
# previous: moved all around them.
# current: “She’ll bring us  mice and things that are nice,” said Sarah.
# next: “I suppose so!” said Percy.
#
# pre-previous: moved all around them.
# previous: “She’ll bring us  mice and things that are nice,” said Sarah.
# current: “I suppose so!” said Percy.
# next: “I want my mummy!” said Bill.
#
# pre-previous: “She’ll bring us  mice and things that are nice,” said Sarah.
# previous: “I suppose so!” said Percy.
# current: “I want my mummy!” said Bill.
# next: They sat and they thought (all owls think a lot) -
#
# pre-previous: “I want my mummy!” said Bill.
# previous: They sat and they thought (all owls think a lot) -
# current: “I  think we should all  sit on my branch,” said Sarah.
# next: And they did, all  three together.
#
# pre-previous: “I  think we should all  sit on my branch,” said Sarah.
# previous: And they did, all  three together.
# current: “Suppose she got lost,” said Sarah.
# next: “Or a fox got her!”
#
# pre-previous: “Suppose she got lost,” said Sarah.
# previous: “Or a fox got her!”
# current: said Percy.
# next: I want my mummy!” said Bill.
#
# pre-previous: “Or a fox got her!”
# previous: said Percy.
# current: I want my mummy!” said Bill.
# next: And  the baby owls closed their owl eyes  and wished their Owl Mother would  come.
#
# pre-previous: The baby owls thought
# previous: (all owls think a lot) -
# current: “I knew it,” said Sarah.
# next: “And I knew it!”
#
# pre-previous: “I knew it,” said Sarah.
# previous: “And I knew it!”
# current: said Percy.
# next: “I love my mummy!” said Bill.
#
# pre-previous: “And I knew it!”
# previous: said Percy.
# current: “I love my mummy!” said Bill.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-b87d8d0cbe69> in <module>
#      14                     print('previous:', sentence_list[sentence_list.index(possible_subject.sent)-1])
#      15                     print('current:', possible_subject.head.sent)
# ---> 16                     print('next:', sentence_list[sentence_list.index(possible_subject.sent)+1])
#      17                     print(' ')
#      18
#
# IndexError: list index out of range

# %%
for title, text in zip(df.Title, df.Text):
    text = text.replace('\n', ' ')
    doc = nlp(text)
    sentence_list = list(doc.sents)
    break

# %%
'"'
# Out:
# '"'

# %%
sentence_list
# Out:
# [ A mouse took a stroll through the deep dark wood.,
#  A fox  saw the mouse and the mouse looked good.,
#  “Where are  you going to, little brown mouse?,
#  Come and have lunch  in my underground house.”,
#  “It’s terribly kind of you,    Fox, but,
#  no — I’m going to have lunch with a gruffalo.”   ,
#  “A gruffalo?,
#  What's a gruffalo?”,
#  “A gruffalo!    ,
#  Why, didn’t you know?     ,
#  He has terrible  tusks, and  terrible claws,     And terrible teeth in his terrible jaws.”   ,
#  “Where are you meeting him?”,
#  Here, by these    rocks,   And his favourite food is roasted fox.”   ,
#  “Roasted fox!,
#  I’m off!”,
#  Fox said.   ,
#  “Goodbye, little mouse," and away he sped.   ,
#  “Silly old Fox!,
#  Doesn’t he know, There’s no such thing as a    gruffalo?,
#  On went the mouse through the deep dark wood.,
#  An owl  saw the mouse and the mouse looked good.,
#  “Where are    you going to, little brown mouse?,
#  Come and have tea in my treetop house.”,
#  “It’s frightfully  nice of you, Owl, hut no,
#  — I’m going to have tea with a    gruffalo.”     ,
#  “A gruffalo?,
#  What's a gruffalo?”   ,
#  “A gruffalo!,
#  Why, didn’t you know?,
#  He has knobbly  knees and  turned-out toes,     And a poisonous wart at the end of his nose.’     ,
#  “Where are you meeti ng him?”,
#  “Here, by this stream,   And his favourite food is owl ice cream.”,
#  “Owl ice cream?,
#  Toowhit toowhoo!,
#  Goodbye, little mouse,” and    away Owl flew.   ,
#  "Silly old Owl!,
#  Doesn’t he know, There’s no such thing as a    gruffalo?”,
#  On went the mouse through the deep dark wood.,
#  A snake  saw the mouse and the mouse looked good.,
#  “Where are    you going to, little brown mouse?   ,
#  Come for a feast in my logpile house.”,
#  “It’s wonderfully good of you, Snake, but no,
#  — I’m having    a feast with a gruffalo.”   ,
#  “A gruffalo?,
#  What’s a gruffalo?”,
#  “A gruffalo!    ,
#  Why, didn’t you know?,
#  His eyes  are orange,
#  , his tongue   is black;     He has purple prickles all over his back.”     ,
#  “Where are you me eting him?",
#  “Here, by this lake,   And his favourite food is scrambled snake.”   ,
#  “Scrambled snake!,
#  It’s time I hid!   ,
#  Goodbye, little mouse,” and away Snake slid.   ,
#  “Silly old Snake!,
#  Doesn’t he know, There's    no such thing as a gruffal . . .   ,
#  Oh!,
#  But who is this creature with terrible claws,    And terrible teeth in his terrible jaws?,
#  He has knobbly knees and turned-out toes     ,
#  And a poisonous wart at the end of his nose.   ,
#  His eyes are orange, his tongue is black;   he has purple prickles all over his back''  ,
#  “Oh help!,
#  Oh no!,
#  It’s    a gruffalo!" .,
#  “My favourite food!",
#  the Gruffalo said.,
#  “You'll    taste good on a slice of bread!”   ,
#  Good?” said the mouse.,
#  “Don’t call me good!,
#  I'm    the scariest creature in this wood.,
#  Just walk behind me and soon you’ll see, Everyone is    afraid of me."   ,
#  All right, said the Gruffalo, bursting w ith laughter.,
#  “You go ahead and I’ll follow after. "   ,
#  They walked and walked till the Gruffalo said, “I hear    a hiss in the leaves ahead. ’   ,
#  "It’s Snake,” said the mouse.,
#  “Why, Snake, hello!”,
#  Snake    took one look at the Gruffalo.,
#  “Oh crumbs!”,
#  he said, “Goodbye, little mouse" And off he    slid to his logpile house.,
#  “You see?" said the mouse.,
#  “I told you so.”    ,
#  “Amazing!”,
#  said the Gruffalo.   ,
#  They waited some more till the Gruffalo said, “I hear    a hoot in the trees ahead. ”,
#  “It’s Owl," said the mouse.,
#  “Why, Owl, hello!”,
#  Owl    took one look at the Gruffalo.,
#  Oh dear!",
#  he said, “Goodbye, little mouse",
#  And off he    flew to his treetop house.,
#  “You see?” said the mouse.,
#  “I told you so.”    ,
#  “Astounding!”,
#  said the Gruffalo.,
#  They walked some more till the Gruffalo said, “I can    hear feet on the path ahead.   ,
#  “It’s Fox,” said the mouse.,
#  “Why, Fox, hello!”,
#  Fox    tool?,
#  one look at the Gruffalo.,
#  “Oh help!”,
#  he said, “Goodbye, little mouse,” And    off he ran to his underground house.,
#  “Well, Gruffalo, said the mouse.,
#  “You see?,
#  Everyone is afraid    of me!,
#  But now my tummy’s beginning to rumble    ,
#  My favourite food is — gruffalo crumble!"   ,
#  “Gruffalo crumble!”,
#  the Gruffalo said, And quick as the wind he    turned and fled.   ,
#  All. was quiet in the deep dark wood?- .; ' The    mouse found a nut and the nut was good.]

# %%
[s for s in sentence_list if 'Good' in str(s)]
# Out:
# [“Goodbye, little mouse," and away he sped.   ,
#  Goodbye, little mouse,” and    away Owl flew.   ,
#  Goodbye, little mouse,” and away Snake slid.   ,
#  Good?” said the mouse.,
#  he said, “Goodbye, little mouse" And off he    slid to his logpile house.,
#  he said, “Goodbye, little mouse",
#  he said, “Goodbye, little mouse,” And    off he ran to his underground house.]

# %%
test=[s for s in sentence_list if 's Snake' in str(s)][0]

# %%
'"' in str(test)
# Out:
# True

# %%
str(test).split('"')
# Out:
# ['', 'It’s Snake,” said the mouse.']

# %%
str(test).split('"')[1][11] == '"'
# Out:
# False

# %%
test
# Out:
# "It’s Snake,” said the mouse.

# %%
tuple(doc.sents)
# Out:
# ( Once there were three baby owls:    Sarah and Percy and Bill  ,
#  They lived in a hole  in the trunk of a tree  with their Owl Mother.  ,
#  The hole had twigs and    leaves and owl feathers in it.,
#  It was their house.    ,
#  One night they woke up and,
#  their Owl Mother was  GONE.,
#  “Where’s Mummy?” asked Sarah.,
#  “Oh my  goodness! said Percy.,
#  “I want my mummy!”,
#  said  Bill.    ,
#  The baby owls thought  (all owls think a lot) -  ,
#  “I think she’s gone hunting, said Sarah.  ,
#  “To get us our food! said Percy.  ,
#  “I want my mummy! said Bill.,
#  > -      ,
#  But their Owl Mother didn’t come.  ,
#  The baby owls,
#  and they sat on the tree and  waited.      ,
#  A big branch for Sarah, a small branch for Percy,  and an old bit of ivy for Bill.,
#  “She’ll be back,” said  Sarah.,
#  “Back soon!” said Percy.  ,
#  “I want my  mummy!” said Bill.      ,
#  9  ,
#  ~  ‘ It was dark in the wood and they had to be brave,  for things,
#  moved all around them.  ,
#  “She’ll bring us  mice and things that are nice,” said Sarah.  ,
#  “I suppose so!” said Percy.  ,
#  “I want my mummy!” said Bill.     ,
#  They sat and they thought (all owls think a lot) -,
#  “I  think we should all  sit on my branch,” said Sarah.,
#  And they did, all  three together.    ,
#  “Suppose she got lost,” said Sarah.  ,
#  “Or a fox got her!”,
#  said Percy.  ,
#  I want my mummy!” said Bill.  ,
#  And  the baby owls closed their owl eyes  and wished their Owl Mother would  come.                                                ,
#  AN D,
#  SHE CAME        ,
#  Soft and silent, she swooped  through the trees to Sarah and  Percy and Bill.    ,
#  “Mummy!”,
#  they cried, and they  flapped and they danced and they  bounced up and down on their  branch.      ,
#  “WHAT’S ALL THE FUSS?  ,
#  their Owl Mother asked.    ,
#  “You knew,
#  I’d come back.’’     ,
#  The baby owls thought       ,
#  (all owls think a lot) -    ,
#  “I knew it,” said Sarah.     ,
#  “And I knew it!”,
#  said Percy.     ,
#  “I love my mummy!” said Bill.   )
