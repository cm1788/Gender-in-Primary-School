# %% [markdown]
# ### Detecting and analysing character speech.
#
# First we need to be able to reliably detect sentence that contain speech. As a first approach: sentences immediately preceeded or follwed by "he/she/they said", where said could be any speech verb...
#
# The we are interested in counting:
# * use of question marks, exclamantion marks
# * total word count
#
# Future (and more complex):
# * female characters speaking to each other
# * interruptions
#
# #### Notes:
#
# * Enormous crocodile: didn't have to edit. More vocabulary. More data for less work.
# * Speech might need a bespoke app for tagging the speaker.

# %%
# coding: ascii

# %%
import os
import pdfplumber
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import spacy
from spacy import displacy
from spacy.lang.en.examples import sentences 

# %matplotlib inline

# %%
nlp = spacy.load("en_core_web_lg")

# %%
labels = pd.read_excel('../Book List Exel April.xlsx', sheet_name='Sheet1')
labels = labels.rename(columns={'Author ': 'Author'})

# %%
os.chdir('../text_pdfs')

# %%
df = pd.DataFrame()

def grab_text(title, labels):
    
    start = labels.loc[labels.Title==title]['Starting Page']
    if len(start)==0:
        print(title, "no start")
        start = 0
    else:
        start = start.values[0]
    end = labels.loc[labels.Title==title]['Ending Page']
    if len(end)==0:
        print(title, "no end")
        end = 0
    else:
        end = end.values[0]
    
    title = title + '.pdf'
    all_text = ''
    with pdfplumber.open(title) as pdf:
        for i, page in enumerate(pdf.pages):
            if i+1 >= start and i < end:
                single_page_text = page.extract_text()

                if single_page_text is not None:
                    all_text = all_text + '\n' + single_page_text
                
    return all_text

df['Title'] = [file.split('.')[0] for file in os.listdir() if file.split('.')[1]=='pdf']
df['Text'] = [grab_text(title, labels) for title in df.Title]

# %%
df.head()
# Out:
#                              Title  \
# 0                     The Gruffalo
# 1                    Peace at Last
# 2                  Kipper's Toybox
# 3           The Hungry Caterpillar
# 4  Harry and the Dinosaurs Go Wild
#
#                                                 Text
# 0  \nA mouse took a stroll through the deep dark ...
# 1  \n \nThe hour was late. \n \nMr Bear was tired...
# 2  \nSomeone or something had been \nnibbling a h...
# 3  \n \nIn the light of the moon a little egg lay...
# 4  \nIt was a long drive to the safari park but i...

# %%
for title, text in zip(df.Title, df.Text):
    text = text.replace('\n', ' ')
    doc = nlp(text)
    sentence_list = list(doc.sents)
    
    protagonist = labels.loc[labels.Title==title]['Protagonist Name'].values
    protagonist_gender = labels.loc[labels.Title==title]['Protagonist Gender'].values

    for possible_subject in doc:
            if possible_subject.dep_ == 'nsubj' and possible_subject.head.pos_ == 'VERB':
                
                if possible_subject.head.lemma_ == "say":
                    print('pre-previous:', sentence_list[sentence_list.index(possible_subject.sent)-2])
                    print('previous:', sentence_list[sentence_list.index(possible_subject.sent)-1])
                    print('current:', possible_subject.head.sent)
                    print('next:', sentence_list[sentence_list.index(possible_subject.sent)+1])
                    print(' ')
# Out:
# pre-previous: “Roasted fox!
# previous: I’m off!”
# current: Fox said.
# next: “Goodbye, little mouse," and away he sped.
#
# pre-previous: It’s    a gruffalo!" .
# previous: “My favourite food!"
# current: the Gruffalo said.
# next: “You'll    taste good on a slice of bread!”
#
# pre-previous: the Gruffalo said.
# previous: “You'll    taste good on a slice of bread!”
# current: Good?” said the mouse.
# next: “Don’t call me good!
#
# pre-previous: the Gruffalo said.
# previous: “You'll    taste good on a slice of bread!”
# current: Good?” said the mouse.
# next: “Don’t call me good!
#
# pre-previous: I'm    the scariest creature in this wood.
# previous: Just walk behind me and soon you’ll see, Everyone is    afraid of me."
# current: All right, said the Gruffalo, bursting w ith laughter.
# next: “You go ahead and I’ll follow after. "
#
# pre-previous: All right, said the Gruffalo, bursting w ith laughter.
# previous: “You go ahead and I’ll follow after. "
# current: They walked and walked till the Gruffalo said, “I hear    a hiss in the leaves ahead. ’
# next: "It’s Snake,” said the mouse.
#
# pre-previous: “You go ahead and I’ll follow after. "
# previous: They walked and walked till the Gruffalo said, “I hear    a hiss in the leaves ahead. ’
# current: "It’s Snake,” said the mouse.
# next: “Why, Snake, hello!”
#
# pre-previous: Snake    took one look at the Gruffalo.
# previous: “Oh crumbs!”
# current: he said, “Goodbye, little mouse" And off he    slid to his logpile house.
# next: “You see?" said the mouse.
#
# pre-previous: “Oh crumbs!”
# previous: he said, “Goodbye, little mouse" And off he    slid to his logpile house.
# current: “You see?" said the mouse.
# next: “I told you so.”
#
# pre-previous: “I told you so.”
# previous: “Amazing!”
# current: said the Gruffalo.
# next: They waited some more till the Gruffalo said, “I hear    a hoot in the trees ahead. ”
#
# pre-previous: “Amazing!”
# previous: said the Gruffalo.
# current: They waited some more till the Gruffalo said, “I hear    a hoot in the trees ahead. ”
# next: “It’s Owl," said the mouse.
#
# pre-previous: said the Gruffalo.
# previous: They waited some more till the Gruffalo said, “I hear    a hoot in the trees ahead. ”
# current: “It’s Owl," said the mouse.
# next: “Why, Owl, hello!”
#
# pre-previous: Owl    took one look at the Gruffalo.
# previous: Oh dear!"
# current: he said, “Goodbye, little mouse"
# next: And off he    flew to his treetop house.
#
# pre-previous: he said, “Goodbye, little mouse"
# previous: And off he    flew to his treetop house.
# current: “You see?” said the mouse.
# next: “I told you so.”
#
# pre-previous: “I told you so.”
# previous: “Astounding!”
# current: said the Gruffalo.
# next: They walked some more till the Gruffalo said, “I can    hear feet on the path ahead.
#
# pre-previous: “Astounding!”
# previous: said the Gruffalo.
# current: They walked some more till the Gruffalo said, “I can    hear feet on the path ahead.
# next: “It’s Fox,” said the mouse.
#
# pre-previous: said the Gruffalo.
# previous: They walked some more till the Gruffalo said, “I can    hear feet on the path ahead.
# current: “It’s Fox,” said the mouse.
# next: “Why, Fox, hello!”
#
# pre-previous: one look at the Gruffalo.
# previous: “Oh help!”
# current: he said, “Goodbye, little mouse,” And    off he ran to his underground house.
# next: “Well, Gruffalo, said the mouse.
#
# pre-previous: “Oh help!”
# previous: he said, “Goodbye, little mouse,” And    off he ran to his underground house.
# current: “Well, Gruffalo, said the mouse.
# next: “You see?
#
# pre-previous: “Oh help!”
# previous: he said, “Goodbye, little mouse,” And    off he ran to his underground house.
# current: “Well, Gruffalo, said the mouse.
# next: “You see?
#
# pre-previous: My favourite food is — gruffalo crumble!"
# previous: “Gruffalo crumble!”
# current: the Gruffalo said, And quick as the wind he    turned and fled.
# next: All. was quiet in the deep dark wood?- .; ' The    mouse found a nut and the nut was good.
#
# pre-previous: “SNORE,” went Mrs  Bear, “SNORE, SNORE, SNORE.”
# previous: “Oh NO!”
# current: said Mr Bear, “I can’t stand THIS.”
# next: So he got up  and went to sleep in Baby Bear’s room.
#
# pre-previous: went Baby Bear, “NYAAOW!
# previous: NYAAOW!”
# current: “Oh NO!” said Mr Bear, “I can’t stand THIS.”
# next: So he got up and went to sleep in the living  room.
#
# pre-previous: CUCKOO!
# previous: CUCKOO!
# current: “Oh NO!” said Mr Bear, “I can’t stand THIS!”
# next: So he went off to sleep in the kitchen.
#
# pre-previous: went the leaky kitchen tap.
# previous: HMMMMMMMMMMM.. went the refrigerator.
# current: “Oh NO,” said Mr Bear,  “I can’t stand THIS.”
# next: So he got up  and went to sleep in the garden.
#
# pre-previous: “MIAAAOW!”
# previous: sang the cats on the wall.
# current: “Oh NO!” said Mr Bear, “I can’t stand  THIS.”
# next: So he went off to sleep in the car.
#
# pre-previous: SHINE,  SHINE . . .
# previous: went the sun.
# current: “Oh NO!” said Mr  Bear, “I can’t stand THIS.”
# next: So he got up and went back into the house.
#
# pre-previous: In the house, Baby Bear was fast asleep, and Mrs  Bear had turned over and wasn’t snoring any  more.
# previous: Mr Bear got into bed and closed his eyes.
# current: “Peace at last,” he said to himself.
# next: BRRRRRRRRRRRRRRR!
#
# pre-previous: went the alarm clock,  BRRRRRR!
# previous: Mrs Bear sat up and rubbed her eyes.
# current: “Good morning, dear,” she said.
# next: “Did you sleep well?”
#
# pre-previous: “Did you sleep well?”
# previous: “Not VERY well, dear,” yawned  Mr Bear.
# current: “Never mind,” said Mrs Bear.
# next: “I’ll bring you a nice cup of tea.”
#
# pre-previous: They nibbled EVERYTHING!
# previous:  Someone or something had been  nibbling a hole in Kipper’s toybox.
# current: ‘I hope my toys are safe,’ said  Kipper.
# next: He emptied them out and  counted them.
#
# pre-previous: ‘One, two, three, four, five,  six, SEVEN!
# previous: That’s wrong!’
# current: he said.
# next: “There should only be six!”
#
# pre-previous: “Big Owl one, Hippopotamus two, Sock Thing  three, Slipper four, Rabbit five, Mr Snake six.
# previous: “That’s better!”
# current: he said.
# next: Kipper put his toys back in the toybox.
#
# pre-previous: ‘One, two, three, four, five, six, seven, EIGHT  NOSES!
# previous: That’s two too many noses!’
# current: said Kipper.
# next: Kipper grabbed Big Owl and threw  him out of the toybox.
#
# pre-previous: Kipper grabbed Big Owl and threw  him out of the toybox.
# previous: ‘ONE!’
# current: he said crossly.
# next: Out went Hippopotamus, ‘TWO!’
#
# pre-previous: Kipper was upset Next to Rabbit,  Sock Thing was his favourite.
# previous: Now he was gone.
# current: ‘I won’t lose any more of you,’ said  Kipper.
# next: He picked up the rest of his toys  and put them in his basket.
#
# pre-previous: Then a little tail appeared.
# previous: A little pink tail.
# current: And  a  little  voice  said,  ‘Don’t  hurt him!’
# next: So it was YOU!
#
# pre-previous: So it was YOU!
# previous: You have been making the hole in  my toybox!’
# current: said Kipper.
# next: It was true.
#
# pre-previous: It was true.
# previous: The mice had been nibbling pieces  of Kipper’s toybox to make their nest
# current: You must promise not to nibble it again,’ said  Kipper.
# next: ‘We promise,’ said the mice.
#
# pre-previous: The mice had been nibbling pieces  of Kipper’s toybox to make their nest
# previous: You must promise not to nibble it again,’ said  Kipper.
# current: ‘We promise,’ said the mice.
# next: M n W
#
# pre-previous: but it was worth it.
# previous: Apatosaurus saw an animal just like Triceratops.
# current: “That’s a    rhinoceros,” said Hany.
# next: “Triceratops has got more horns.”
#
# pre-previous: “Triceratops has got more horns.”
# previous: Mum liked the giraffes best and Nan-    liked the zebras.
# current: The monkeys were funny but the    man said not to feed them.
# next: Sam asked him if they had pandas but the man said    no, they were endangered animals.
#
# pre-previous: Mum liked the giraffes best and Nan-    liked the zebras.
# previous: The monkeys were funny but the    man said not to feed them.
# current: Sam asked him if they had pandas but the man said    no, they were endangered animals.
# next: Harry wanted to know what endangered meant;   Sam said he was too little to understand.
#
# pre-previous: The monkeys were funny but the    man said not to feed them.
# previous: Sam asked him if they had pandas but the man said    no, they were endangered animals.
# current: Harry wanted to know what endangered meant;   Sam said he was too little to understand.
# next: Nan helped.
#
# pre-previous: People kept    hunting them so there were only a few left in the whole world.
# previous: Harry really wanted to help but he had no money.
# current: “I  want to save some animals,” he said.
# next: “What can I do, Mum?”
#
# pre-previous: “I  want to save some animals,” he said.
# previous: “What can I do, Mum?”
# current: Sam said, “Tuh!
# next: What a waste of time!”
#
# pre-previous: Sam said, “Tuh!
# previous: What a waste of time!”
# current: She said he was miles too small to make any difference.
# next: That’s why Harry made her do a smudge with her    lipstick.
#
# pre-previous: Mum took Harry off to settle down.
# previous: Then they looked on the    Internet and found lots of endangered animals.
# current: Mum said why not do a poster?
# next: Harry could put it up  in his window.
#
# pre-previous: He got out his drawing stuff  straight away.
# previous: Trouble was, it was hard to know which    animal to save first.
# current: The dinosaurs said, “Raaaah!
# next: We want to save some BIG animals!1
#
# pre-previous: Tyrannosaurus did a polar bear.
# previous: Pterodactyl asked Harry to help him do a gorilla.
# current: “Wait till I’ve finished my blue whale,” said Harry.
# next: “Blue whales are bigger than trains, bigger than    dinosaurs, bigger than thirty-two elephants!”
#
# pre-previous: Stegosaurus did an army tank.
# previous: “Army tanks don’t need saving!”
# current: said Triceratops.
# next: “Do a tree frog instead.”
#
# pre-previous: said Triceratops.
# previous: “Do a tree frog instead.”
# current: Mum said the drawings were excellent.
# next: She helped put the words on.
#
# pre-previous: She helped put the words on.
# previous: LEVS SAVE THESE ENDANGERED ANIMALS!
# current: Nan said, “Why not talk to Mr Bopsom?
# next: He might put up a poster in his shop window!
#
# pre-previous: Mr Bopsom loved the pictures but he thought they might be a    bit too small for a poster.
# previous: He asked Harry if he could draw them bigger.
# current: Harry said no, sorry, his pictures always came out small.
# next: That’s a shame,” said Mr Bopsom.
#
# pre-previous: He asked Harry if he could draw them bigger.
# previous: Harry said no, sorry, his pictures always came out small.
# current: That’s a shame,” said Mr Bopsom.
# next: “Because saving animals is    important!”
#
# pre-previous: The very next day, Mr Bopsom was on the phone. ....
# previous: “I’ve had an idea!”
# current: he said.
# next: “Can you do me lots more    pictures?”
#
# pre-previous: When Harry went into the shop two weeks later he was    amazed!
# previous: Mr Bopsom had made all the drawings into cards.
# current: He said that every time somebody bought a card, some of    the money went to save endangered animals.
# next: Everybody loved them.
#
# pre-previous: He said that every time somebody bought a card, some of    the money went to save endangered animals.
# previous: Everybody loved them.
# current: They said, “Marvellous!”
# next: “What a brilliant idea!”
#
# pre-previous: The lady from the paper came and was very impressed.
# previous: “What a  wonderful thing you’ve done!”
# current: she said.
# next: “Raahh!” said Apatosaurus.
#
# pre-previous: “What a  wonderful thing you’ve done!”
# previous: she said.
# current: “Raahh!” said Apatosaurus.
# next: “Save the strawberry poison arrow frog!”
#
# pre-previous: “What a  wonderful thing you’ve done!”
# previous: she said.
# current: “Raahh!” said Apatosaurus.
# next: “Save the strawberry poison arrow frog!”
#
# pre-previous: “Raahh!” said Apatosaurus.
# previous: “Save the strawberry poison arrow frog!”
# current: “Raahh!” said Pterodactyl.
# next: “Save the teeny blue tongued skink!”
#
# pre-previous: “Raahh!” said Apatosaurus.
# previous: “Save the strawberry poison arrow frog!”
# current: “Raahh!” said Pterodactyl.
# next: “Save the teeny blue tongued skink!”
#
# pre-previous: “Raahh!” said Pterodactyl.
# previous: “Save the teeny blue tongued skink!”
# current: And Harry said, “Quite right, my dinosaurs!
# next: Because even    if you are as tiny as a tick on the tail of a green turtle, you can    still do something that makes a BIG difference.
#
# pre-previous: And he ended up in a hospital bed
# previous: In a faraway part of town.
# current: “Goodbye,” McTat said.
# next: “I must get back to Fred.”
#
# pre-previous: and on.
# previous: A week later, Sock took a stroll round the block And found her new    friend looking thin.
# current: “He’s gone off and left me!’' said Tabby McTat.
# next: Then Sock said, “My people, Prunella and Pat, Would gladly find    room for a fine tabby cat.”
#
# pre-previous: A week later, Sock took a stroll round the block And found her new    friend looking thin.
# previous: “He’s gone off and left me!’' said Tabby McTat.
# current: Then Sock said, “My people, Prunella and Pat, Would gladly find    room for a fine tabby cat.”
# next: ' She was right and they took McTat in.'
#
# pre-previous: But he dreamed of his friend    with the old checked hat
# previous: And always woke up with a meW-
# current: And often he said, “What’s happened to Fred?”
# next: And his paws  took him hack to the square. '
#
# pre-previous: And he pulled out this… and he pulled out that….And people threw    coins in the tall black hat,
# previous: But the busker was never there.
# current: One morning Sock said, “Look under the bed And see the    three kittens I’ve had!”
# next: And Soames looked like this, and Susan like that,
#
# pre-previous: •But nohody wanted poor Samuel Sprat.
# previous: •
# current: They all    said, “His voice is too loud.”
# next: Now Tabby McTat was a home-loving cat.
#
# pre-previous: And one day be called for his wife and his son   And be told them,
# previous: “There’ s something that has to be done.
# current: I must go and find him,” he said.
# next: So up and down . . .
#
# pre-previous: Then out from a shadow sprang Samuel Sprat.
# previous: “Oh please let    ME be the busker’s cat!"
# current: He said with his deafening mew.
# next: o, C
#
# pre-previous: She had to study the Romans for homework.
# previous: “What are Romans?” asked Harry.
# current: Sam said they were our ancestors, but he was too young to    understand.
# next: Harry wanted to take the dinosaurs to see them.
#
# pre-previous: Sam said they were our ancestors, but he was too young to    understand.
# previous: Harry wanted to take the dinosaurs to see them.
# current: Sam said, “No way!”
# next: She said Harry would just get bored and silly.
#
# pre-previous: Harry wanted to take the dinosaurs to see them.
# previous: Sam said, “No way!”
# current: She said Harry would just get bored and silly.
# next: That    was why Sam’s homework got smudged
#
# pre-previous: That    was why Sam’s homework got smudged
# previous: Mum made them both settle down.
# current: She said a    museum would be a fine outing for everybody.
# next: “I’d love to go,” said Nan.
#
# pre-previous: Mum made them both settle down.
# previous: She said a    museum would be a fine outing for everybody.
# current: “I’d love to go,” said Nan.
# next: The museum was bigger than a hospital.
#
# pre-previous: “Are these ancestors?”
# previous: asked Harry.
# current: Mum said yes, everybody in the world came from cavemen.
# next: They lit    fires and did hunting.
#
# pre-previous: “Are Egyptians ancestors?”
# previous: asked Harry.
# current: “Yes, but not the right ones,” said Sam.
# next: “We want the Romans.
#
# pre-previous: But what a lot of old pots, broken ones too!
# previous: Sam started doing drawing.
# current: “We’ve seen the Romans now,” said Harry.
# next: “I’m hungry!
#
# pre-previous: “Raaah!
# previous: Anchisaurus pinched me!”
# current: said Stegosaurus.
# next: “He’s taking up all the room!”
#
# pre-previous: said Stegosaurus.
# previous: “He’s taking up all the room!”
# current: said Anchisaurus.
# next: “Behave!”
#
# pre-previous: said Anchisaurus.
# previous: “Behave!”
# current: said Harry in a loud voice.
# next: “Look, Harry is being silly!”
#
# pre-previous: groaned Sam.
# previous: “I knew it!
# current: “I think the dinosaurs need a run about,” said Harry.
# next: Mum said better    not.
#
# pre-previous: “I knew it!
# previous: “I think the dinosaurs need a run about,” said Harry.
# current: Mum said better    not.
# next: They might get lost.
#
# pre-previous: Mum said better    not.
# previous: They might get lost.
# current: “Come on, let’s get something to eat,” she said.
# next: “Afterwards we’ll    come back here, so Sam can finish her studies.”
#
# pre-previous: Nan and Harry and the dinosaurs    waited at a table while Mum and Sam went to queue up.
# previous: “Look, I’m a caveman!
# current: Raaah!” said Triceratops.
# next: “Look, I’m a Roman!
#
# pre-previous: Nan and Harry and the dinosaurs    waited at a table while Mum and Sam went to queue up.
# previous: “Look, I’m a caveman!
# current: Raaah!” said Triceratops.
# next: “Look, I’m a Roman!
#
# pre-previous: Raaah!” said Triceratops.
# previous: “Look, I’m a Roman!
# current: Raaah!” said Pterodactyl.
# next: “Look, I’m a mummy!
#
# pre-previous: Raaah!” said Triceratops.
# previous: “Look, I’m a Roman!
# current: Raaah!” said Pterodactyl.
# next: “Look, I’m a mummy!
#
# pre-previous: Raaah!” said Pterodactyl.
# previous: “Look, I’m a mummy!
# current: Raaah!” said Tyrannosaurus.
# next: After lunch, everyone felt a lot better and they set off back    to the Romans.
#
# pre-previous: Raaah!” said Pterodactyl.
# previous: “Look, I’m a mummy!
# current: Raaah!” said Tyrannosaurus.
# next: After lunch, everyone felt a lot better and they set off back    to the Romans.
#
# pre-previous: After lunch, everyone felt a lot better and they set off back    to the Romans.
# previous: But it wasn't long before Anchisaurus got bored.
# current: “I’m bored too!” said Tyrannosaurus. ‘
# next: Never mind,” said Harry, “it’s your turn to do studying.
#
# pre-previous: But it wasn't long before Anchisaurus got bored.
# previous: “I’m bored too!” said Tyrannosaurus. ‘
# current: Never mind,” said Harry, “it’s your turn to do studying.
# next: Pay attention, my dinosaurs.”
#
# pre-previous: got lost
# previous: “Oh no!
# current: Where’s Harry?” said Mum.
# next: “Quick!   Let’s find the person in charge!”
#
# pre-previous: Where’s Harry?” said Mum.
# previous: “Quick!   Let’s find the person in charge!”
# current: Sam said Harry was stupid.
# next: “I bet he’s gone off on a bus!”
#
# pre-previous: Sam said Harry was stupid.
# previous: “I bet he’s gone off on a bus!”
# current: she said.
# next: “Nonsense!”
#
# pre-previous: she said.
# previous: “Nonsense!”
# current: said Nan.
# next: “I know where   we’ll find him!”
#
# pre-previous: They followed Nan to the prehistoric Hall.
# previous: “There he is!”
# current: said Nan.
# next: “I    knew it!”
#
# pre-previous: “Boys come from cavemen and Romans and Egyptians,” he explained.
# previous: “But these are your ancestors.”
# current: So Tyrannosaurus said “Raaah!”
# next: to his ancestor.
#
# pre-previous: All except Pterodactyl, who gave his ancestor a nose-rub.
# previous: “Now, young man!”
# current: said the person in charge.
# next: “We had better look for your mum.
#
# pre-previous: “We had better look for your mum.
# previous: Could you tell me your name?”
# current: Harry said his name, address and telephone   number, no problem at all.
# next: All the people said very good, clever boy!
#
# pre-previous: Could you tell me your name?”
# previous: Harry said his name, address and telephone   number, no problem at all.
# current: All the people said very good, clever boy!
# next: Nan rushed over.
#
# pre-previous: “He’s with us!”
# previous: she called proudly.
# current: “Harry!” said Mum.
# next: “We thought we’d lost you!”
#
# pre-previous: “He’s with us!”
# previous: she called proudly.
# current: “Harry!” said Mum.
# next: “We thought we’d lost you!”
#
# pre-previous: “We thought we’d lost you!”
# previous: “I wasn’t lost!”
# current: said Harry.
# next: “1 was with    my dinosaurs.”
#
# pre-previous: and another blue one. . .’
# previous: Percy was counting balloons.
# current: “I wonder where they’re coming from,” he said to himself.
# next: “Somebody must have had a party.”
#
# pre-previous: “Somebody must have had a party.”
# previous: He put down his trowel and wiped    his hands.
# current: “Well, if nobody wants them,” he said,    “I think I’ll help myself.”
# next: Percy chased after  the balloons as  they floated past him    on the breeze.
#
# pre-previous: He could    hear a faint sound coining from a tree stump nearby.
# previous: It was not a happy    sound.
# current: “Someone’s crying,” said Percy.
# next: “Oh dear.”
#
# pre-previous: Sitting on the tree stump, and looking    very upset, was a hedgehog.
# previous: Two mice   were doing their best to comfort him.
# current: “Goodness me,” said Percy.
# next: “Whatever    is the matter?”
#
# pre-previous: “Goodness me,” said Percy.
# previous: “Whatever    is the matter?”
# current: It’s all these balloons,” said the    hedgehog.
# next: Then, in between sniffs and sobs, he explained to Percy  how he had always loved balloons.
#
# pre-previous: “It’s just not fair!”
# previous: And the hedgehog burst into tears    again.
# current: “You poor thing,” said Percy.
# next: He tried to put his arm around the    hedgehog but took it away at once.
#
# pre-previous: “You poor thing,” said Percy.
# previous: He tried to put his arm around the    hedgehog but took it away at once.
# current: “Ouch,” he said.
# next: Then Percy took one of his thick  gardening gloves out of his pocket and put it    on.
#
# pre-previous: Then Percy took one of his thick  gardening gloves out of his pocket and put it    on.
# previous: The hedgehog nestled into his hand.
# current: “I think everyone should be able to play with balloons,” said Percy.
# next: “And that includes    hedgehogs.”
#
# pre-previous: He set the hedgehog down on a workbench and then he took a tin    from a shelf.
# previous: He opened the lid.
# current: “What’s Percy doing?” said one of the    mice.
# next: “What’s in that box?”
#
# pre-previous: “What’s Percy doing?” said one of the    mice.
# previous: “What’s in that box?”
# current: “I don’t know,” said the other mouse.
# next: “I can’t see properly.”
#
# pre-previous: The mice didn’t have to wait long to find  out.
# previous: Percy picked up the hedgehog and    brought him outside.
# current: “There!” said Percy.
# next: “A good idea, even if I say so myself!
#
# pre-previous: Percy picked up the hedgehog and    brought him outside.
# previous: “There!” said Percy.
# current: “A good idea, even if I say so myself!
# next: I think those    balloons will be safe now.”
#
# pre-previous: He thought how smart he must look,    wearing his corks.
# previous: Percy caught hold of a bright yellow    balloon.
# current: “Here you are,” said Percy as he  handed it to the hedgehog.
# next: “Your very    first balloon.”
#
# pre-previous: “Your very    first balloon.”
# previous: The hedgehog took the balloon and    with a great big smile on his face, he scampered off with the balloon floating    beside him.
# current: “Another satisfied customer,” said    Percy, feeling pleased with himself.
# next: Percy turned to go back to his hut.
#
# pre-previous: But    suddenly, there came a loud BANG!
# previous: “
# current: Oops!” said Percy.
# next: “One of the corks  must have come off.
#
# pre-previous: But    suddenly, there came a loud BANG!
# previous: “
# current: Oops!” said Percy.
# next: “One of the corks  must have come off.
#
# pre-previous:    It was a bright, cold winter’s day.
# previous: Snow had fallen in the night and now everything in the park had been    turned into a guessing game.
# current: “It looks wonderful,” said Percy the    park keeper, “but it makes a lot of work.”
# next: Standing next to Percy was a rather    old and cross looking rabbit.
#
# pre-previous: “It looks wonderful,” said Percy the    park keeper, “but it makes a lot of work.”
# previous: Standing next to Percy was a rather    old and cross looking rabbit.
# current: “Well, quite so,” said the rabbit.
# next: “But now, what about these mice?
#
# pre-previous: After all, this  was no fun for an old rabbit who only  wanted to curl up and sleep through the    cold weather.
# previous: I     “Now come along
# current: , you mice,” said Percy.
# next: “You must go and play somewhere  else.
#
# pre-previous: The mice looked very disappointed.
# previous: Slowly they walked away, dragging their    toboggans behind them.
# current: The old rabbit said thank you to Percy and    then disappeared into his burrow.
# next: M. S    Percy got on with clearing the snow.
#
# pre-previous: Percy worked hard all morning.
# previous: He mopped his brow again and   looked at his work.
# current: “Very good,” he said to himself.
# next: “I think I deserve a spot of lunch.”
#
# pre-previous: “I think I deserve a spot of lunch.”
# previous: Percy reached for his bag and pulled    out a flask.
# current: “That’s funny,” he said.
# next: “I’m sure I put    the cup on the top this morning.”
#
# pre-previous: “I know, I’ll have mg yogurt first and    drink from the empty carton.”
# previous: Percy took out a strawberry  yogurt and began to    rummage through his bag. ‘
# current: That’s odd,” he said.
# next: “No spoon.
#
# pre-previous: It felt colder to Percy as he went back to    work.
# previous: He reached for his scarf and his   cap, but now they had disappeared too!
# current: “This is most peculiar,” said Percy.
# next: Then, as he gazed around looking for his  cap and scarf, Percy was amazed to see his    gloves walking off by themselves!
#
# pre-previous: “This is most peculiar,” said Percy.
# previous: Then, as he gazed around looking for his  cap and scarf, Percy was amazed to see his    gloves walking off by themselves!
# current: “I must be dreaming,” said Percy.
# next: “I’d like to be dreaming,” said a cross    voice.
#
# pre-previous: Then, as he gazed around looking for his  cap and scarf, Percy was amazed to see his    gloves walking off by themselves!
# previous: “I must be dreaming,” said Percy.
# current: “I’d like to be dreaming,” said a cross    voice.
# next: It was the old rabbit again.
#
# pre-previous: Then, as he gazed around looking for his  cap and scarf, Percy was amazed to see his    gloves walking off by themselves!
# previous: “I must be dreaming,” said Percy.
# current: “I’d like to be dreaming,” said a cross    voice.
# next: It was the old rabbit again.
#
# pre-previous: Percy followed.
# previous: “Look!”
# current: said the rabbit.
# next: Percy looked.
#
# pre-previous: “You’re not going to tell us to    stop, are you?”
# previous: Percy glanced at the old rabbit.
# current: “Well. . .no,” he said to the mice.
# next: “We just wondered if you could have a marvellous    time a little   more quietly?”
#
# pre-previous: “We’ll try!”
# previous: they squeaked loudly.
# current: “Come on,” said Percy to the rabbit.
# next: “I think I’ve got some cotton wool  in my bag.
# pre-previous: Harry wanted to take his dinosaurs, but they  were hiding all over the place.
# previous: He called all  their names.
# current: He said, “Get in the bucket, my Stegosaurus.”
# next: And out came Stegosaurus from under the  pillow.
#
# pre-previous: He said, “Get in the bucket, my Stegosaurus.”
# previous: And out came Stegosaurus from under the  pillow.
# current: He said, “Get in the bucket, my Triceratops.”
# next: And out came Triceratops from inside the  drawer.
#
# pre-previous: He didn’t want to go  because he had a lot of teeth.
# previous: He thought Mr Drake might do drilling on them.
# current: Harry said, “Don’t worry, because when we get there, I shall  press a magic button on my bucket, and that will make you  grow big.”
# next: In the waiting room, the nurse said, “Hello,  Harry.
#
# pre-previous: He thought Mr Drake might do drilling on them.
# previous: Harry said, “Don’t worry, because when we get there, I shall  press a magic button on my bucket, and that will make you  grow big.”
# current: In the waiting room, the nurse said, “Hello,  Harry.
# next: Are you a good boy?”
#
# pre-previous: In the waiting room, the nurse said, “Hello,  Harry.
# previous: Are you a good boy?”
# current: Harry said, “I am, but my dinosaurs bite.”
# next: Mr Drake called,  “Next please!”
#
# pre-previous: Harry wasn’t sure about the big chair.
# previous: He thought maybe that  was where Mr Drake did the drilling.
# current: “Come and have a ride in my chair,” said Mr Drake.
# next: “It goes up and down.”
#
# pre-previous: He  whispered to him not to worry, then he  pressed the magic button…
# previous: Tyrannosaurus grew VERY BIG!
# current: “Open wide,” said Mr Drake, and
# next: then  he turned around ...
#
# pre-previous: then  he turned around ...
# previous: “RAAAAHH!”
# current: said Tyrannosaurus.
# next: “Help!”
#
# pre-previous: Then Harry and his dinosaurs  all had a ride together.
# previous: They opened their mouths wide for  Mr Drake and all went, ‘RAAAAHH!’
# current: Mr Drake said, “What a lot of teeth!
# next: Will they bite me?”
#
# pre-previous: Mr Drake said, “What a lot of teeth!
# previous: Will they bite me?”
# current: Harry said, “They only bite drills.”
# next: “You are all good brushers,” said Mr Drake,  “so no drills today, only a look and a rinse.”
#
# pre-previous: Will they bite me?”
# previous: Harry said, “They only bite drills.”
# current: “You are all good brushers,” said Mr Drake,  “so no drills today, only a look and a rinse.”
# next: All the dinosaurs liked riding
#
# pre-previous: “Another bucket of mouthwash, Joan!” called Mr  Drake.
# previous: Going home, Mum let Harry choose a book from the library for  being so good.
# current: “Let’s have a shark book!” said Harry.
# next: “RAAAAHH!”
#
# pre-previous: “Let’s have a shark book!” said Harry.
# previous: “RAAAAHH!”
# current: said the dinosaurs.
# next: “Sharp teeth!
#
# pre-previous: Look what we’ve found!”
# previous: Just ahead of him, a squirrel friend and the mole were    standing over a heap of twigs.
# current: “Hello,” said Percy.
# next: “That looks like an old nest.”
#
# pre-previous: He    picked it up.
# previous: “I shouldn’t think anyone lives in it now.”
# current: “Then you’d be wrong,” said a little voice.
# next: A small feathery head stuck itself  out from beneath the twigs.
#
# pre-previous: “I live in it.
# previous: And you’re holding me upside down.”
# current: “I’m so sorry,” said Percy.
# next: He turned  the nest over.
#
# pre-previous: He turned  the nest over.
# previous: “I thought you would have    gone with your friends and relations.”
# current: “Can’t fly,” said the little bird.
# next: “I didn’t    get the hang of it.”
#
# pre-previous: This little fellow can’t fly.”
# previous: “Flying?”
# current: said the owl, as she swooped  overhead.
# next: “Nothing to it,” she hooted, as    she went into an impressive spin.
#
# pre-previous: The owl hit a pine tree.
# previous: Pine cones rained down on the  squirrel and the mole, followed by the owl in a dazed and untidy    heap.
# current: “Well,” said Percy, “I think there’s    a lesson for us all.”
# next: “Percy,” said the squirrel, “have you    got any string?”
#
# pre-previous: Pine cones rained down on the  squirrel and the mole, followed by the owl in a dazed and untidy    heap.
# previous: “Well,” said Percy, “I think there’s    a lesson for us all.”
# current: “Percy,” said the squirrel, “have you    got any string?”
# next: Percy felt in his pocket.
#
# pre-previous: “Percy,” said the squirrel, “have you    got any string?”
# previous: Percy felt in his pocket.
# current: “Here’s a piece,” he said.
# next: “Why do you want it?
#
# pre-previous: “Why do you want it?
# previous: The squirrel jumped to his feet.
# current: “Come on,” he said to the little   bird.
# next: “I’ll give you a piggy-back.”
#
# pre-previous: “He needs to get used to heights,”    explained the squirrel.
# previous: When he reached the top, the    squirrel tied the string between   two branches.
# current: “It’s a tightrope,” he said.
# next: “Follow me!”
#
# pre-previous: As Percy plodded on he saw his friend the fox  coming up the path  towards him.
# previous: The fox was on  his way home too.
# current: “Good night,” said Percy as they passed each    other.
# next: “Good night, hic-Percy,” answered   the fox.
#
# pre-previous: It was  then that he had learnt that it is not a  good idea to laugh and drink at the same    time.
# previous: He had had hiccups all afternoon.
# current: “I wonder if hic-Percy knows a good  cure for hic-cups,” the fox said to himself.
# next: “I th-hic
#
# pre-previous: “I wonder if hic-Percy knows a good  cure for hic-cups,” the fox said to himself.
# previous: “I th-hic
# current: I’ll ask him,” he said and with    that he turned and followed after Percy.
# next: When he got back to his hut, Percy    remembered that he still had one or two jobs to do.
#
# pre-previous: When he got back to his hut, Percy    remembered that he still had one or two jobs to do.
# previous: First, he watered some    plants.
# current: “I’d better get my washing in too,” said  Percy.
# next: “Then, it’s two boiled eggs for me and a    pile of toast soldiers.”
#
# pre-previous: Percy had never met a ghost before.
# previous: He felt he should introduce himself.
# current: But what should he say to a ghost?
# next: Percy listened hard.
#
# pre-previous: “Could you possibly turn me the right    way up?”
# previous: Percy helped the fox back on to his feet.
# current: “You gave me quite a shock,” said   Percy.
# next: “I gave myself one,” said the fox.
#
# pre-previous: Percy helped the fox back on to his feet.
# previous: “You gave me quite a shock,” said   Percy.
# current: “I gave myself one,” said the fox.
# next: “But it seems    to have cured my hiccups!”
#
# pre-previous:    “Can I go to the moon?”
# previous: asked Baby Bear.
# current: “No, you can’t,” said Mrs Bear.
# next: “It’s bathtime.
#
# pre-previous: out into the night.
# previous: An owl flew past.
# current: “That’s a smart rocket,” he said.
# next: “Where are you off to?”
#
# pre-previous: “That’s a smart rocket,” he said.
# previous: “Where are you off to?”
# current: “The moon,” said Baby Bear.
# next: “Would you like to  come too?”
#
# pre-previous: “The moon,” said Baby Bear.
# previous: “Would you like to  come too?”
# current: “Yes please,” said the owl.
# next: An aeroplane roared out of the clouds.
#
# pre-previous: On and on
# previous: they flew, up and up, above the clouds, past  millions of stars till at last they landed on the moon.
# current: “There’s nobody here,” said Baby Bear.
# next: “There are no trees,” said the owl.
#
# pre-previous: they flew, up and up, above the clouds, past  millions of stars till at last they landed on the moon.
# previous: “There’s nobody here,” said Baby Bear.
# current: “There are no trees,” said the owl.
# next: “It’s a bit boring,” said Baby Bear.
#
# pre-previous: “There’s nobody here,” said Baby Bear.
# previous: “There are no trees,” said the owl.
# current: “It’s a bit boring,” said Baby Bear.
# next: “Shall we have a picnic?”
#
# pre-previous: “It’s a bit boring,” said Baby Bear.
# previous: “Shall we have a picnic?”
# current: “What a good idea,” said the owl.
# next: “We’d better go,” said Baby Bear, “
#
# pre-previous: “Shall we have a picnic?”
# previous: “What a good idea,” said the owl.
# current: “We’d better go,” said Baby Bear, “
# next: My  bath must be ready by now,” Off they  went, down and down.
#
# pre-previous: My  bath must be ready by now,” Off they  went, down and down.
# previous: The owl got out  and flew away.
# current: “Goodbye,” he said.
# next: “It  was so nice to meet you.”
#
# pre-previous: she gasped as she led him away to  the bathroom.
# previous: “Why, you look as if you’ve been up the chimney.”
# current: “As a matter of fact,” said Baby Bear, “I have been up  the chimney.
# next: I found a rocket and went to  visit the moon.”
#
# pre-previous: I found a rocket and went to  visit the moon.”
# previous: Mrs Bear laughed.
# current: “You and your stories,” she said.
# next: “Whatever next?”
# pre-previous: He tried his  hardest every day to win a golden star.
# previous: All the dragons in Year One were learning how to fly.
# current: “High!” said Madam Dragon.
# next: “Way up in the sky!
#
# pre-previous: then crashed into a tree.
# previous: Just then, a little girl ca me by.
# current: “Oh, please don’t cry,” she said.
# next: “Perhaps you’d like a nice sticky  plaster for your head?”
#
# pre-previous: “Oh, please don’t cry,” she said.
# previous: “Perhaps you’d like a nice sticky  plaster for your head?”
# current: “What a good idea!” said Zog.
# next: Then up and off he  flew, His plaster  gleaming pinkly as he zigzagged through the blue.
#
# pre-previous: “Oh, please don’t cry,” she said.
# previous: “Perhaps you’d like a nice sticky  plaster for your head?”
# current: “What a good idea!” said Zog.
# next: Then up and off he  flew, His plaster  gleaming pinkly as he zigzagged through the blue.
#
# pre-previous: A year went by, and in Year Two the dragons lear ned to roar.
# previous: •
# current: “More!” said Madam Dragon.
# next: “Louder, I implore! '
#
# pre-previous: but then his throat grew hoarse.
# previous: Just then the girl came by again.
# current: She  said, “What rotten luck!
# next: Perhaps you’d like  a nice soothing peppermint to suck?”
#
# pre-previous: She  said, “What rotten luck!
# previous: Perhaps you’d like  a nice soothing peppermint to suck?”
# current: “What a good idea!” said Zog.
# next: Then up and off he flew,   And breathing fumes of peppermint he zigzagged through the blue.
#
# pre-previous: She  said, “What rotten luck!
# previous: Perhaps you’d like  a nice soothing peppermint to suck?”
# current: “What a good idea!” said Zog.
# next: Then up and off he flew,   And breathing fumes of peppermint he zigzagged through the blue.
#
# pre-previous: Then up and off he flew,   And breathing fumes of peppermint he zigzagged through the blue.
# previous: A year went by, and in Year Three the dragons learned to blow.
# current: “No!” said Madam  Dragon.
# next: “Breathe out fire, not snow!
#
# pre-previous: He twirled around in triumph ...   and his wing tip caught alight.
# previous: Just then the girl came by again.
# current: She said, “You poor old th ing.
# next: Perhaps you’d like a nice stretchy bandage for your wing?”
#
# pre-previous: She said, “You poor old th ing.
# previous: Perhaps you’d like a nice stretchy bandage for your wing?”
# current: “What a good idea!” said Zog.
# next: Then up a nd off
#
# pre-previous: She said, “You poor old th ing.
# previous: Perhaps you’d like a nice stretchy bandage for your wing?”
# current: “What a good idea!” said Zog.
# next: Then up a nd off
#
# pre-previous: All the Year Four dragons were learning —
# previous: c an you guess?
# current: “Yes!” said  Madam Dragon.
# next: “How to capture a princess!
#
# pre-previous: ‘I’ll never win a golden star!”
# previous: Just then he saw the girl.
# current: ‘Perhaps,” she said, “you’d like to capture met
# next: I’m Princess Pearl.”
#
# pre-previous: ‘Perhaps,” she said, “you’d like to capture met
# previous: I’m Princess Pearl.”
# current: “What a good idea!” said Zog.
# next: Then up and off t hey flew, The princess gripping tightly as they zigzagged  through the blue.
#
# pre-previous: ‘Perhaps,” she said, “you’d like to capture met
# previous: I’m Princess Pearl.”
# current: “What a good idea!” said Zog.
# next: Then up and off t hey flew, The princess gripping tightly as they zigzagged  through the blue.
#
# pre-previous: “What a good idea!” said Zog.
# previous: Then up and off t hey flew, The princess gripping tightly as they zigzagged  through the blue.
# current: “Ah,” said Madam Dragon.
# next: “Our first princess so far!
#
# pre-previous: She took the dragons’ temperatures,  and nursed them when they fell.
# previous: A year went by and, in Year Five, the dragons learned to fight.
# current: “Right!” said Madam Dragon.
# next: “Here comes a real live knight!”
#
# pre-previous: “Right!” said Madam Dragon.
# previous: “Here comes a real live knight!”
# current: Up spoke the knight: “ My name,” he said, “is  Gadabout the Great.
# next: I’ve come to rescue Princ ess Pearl.
#
# pre-previous: “I want to be a doc tor, and travel here and there, Listening to people’s chests and  giving them my care. ;M=, rao!-
# previous: „daimed the and took h. offh.
# current: 1 d rather wear a nice twisty stethoscope,” he said.
# next: “Perhaps, Princess, you’ll train me up?”
#
# pre-previous: “Perhaps, Princess, you’ll train me up?”
# previous: And Pearl repl ied, “Of course, But I  don’t see how the two of us could fit upon your horse.”
# current: Then Zog said, “Flying doctors!
# next: I’d love to join the crew.
#
# pre-previous: I’d love to join the crew.
# previous: If you’ll let me be your  ambulance, then I can carry you.”
# current: “Bravo!” said Madam Dragon.
# next: “An  excellent  career!”
#
# pre-previous: I’d love to join the crew.
# previous: If you’ll let me be your  ambulance, then I can carry you.”
# current: “Bravo!” said Madam Dragon.
# next: “An  excellent  career!”
#
# pre-previous: Then Madam Dragon told the horse, “I really hope you’ ll stay.
# previous: I’ll let you be my pupils’ pet, and feed you lots of hay.”
# current: “What a good idea!” said Zog.
# next: Then  up and off he flew, The Flying Doctors waving  as they zigzagged through the blue.
#
# pre-previous: Then Madam Dragon told the horse, “I really hope you’ ll stay.
# previous: I’ll let you be my pupils’ pet, and feed you lots of hay.”
# current: “What a good idea!” said Zog.
# next: Then  up and off he flew, The Flying Doctors waving  as they zigzagged through the blue.
#
# pre-previous: Mr Croc told everyone his good idea.
# previous: He told them they were going to work in teams.
# current: He  said each team was going to build a go-kart out of  the wood and the wheels.
# next: He said that when the go- karts were finished, they would race them round the  swamp.
#
# pre-previous: He told them they were going to work in teams.
# previous: He  said each team was going to build a go-kart out of  the wood and the wheels.
# current: He said that when the go- karts were finished, they would race them round the  swamp.
# next: Then Mr Croc asked who would like to drive  the go-karts.
#
# pre-previous: He  told Monkey that he was going to drive a go-kart, too.
# previous: Monkey was very excited.
# current: Mr Croc said that everyone needed to listen to the  instructions.
# next: He said it was important to listen  carefully.
#
# pre-previous: Monkey was very excited.
# previous: Mr Croc said that everyone needed to listen to the  instructions.
# current: He said it was important to listen  carefully.
# next: He said everyone had to work as a team.
#
# pre-previous: Mr Croc said that everyone needed to listen to the  instructions.
# previous: He said it was important to listen  carefully.
# current: He said everyone had to work as a team.
# next: They had to work together to build the go-karts.
#
# pre-previous: He said everyone had to work as a team.
# previous: They had to work together to build the go-karts.
# current: He  said they had to check they were safe to race, too.
# next: Everyone listened carefully.
#
# pre-previous: Little Lion had to fix the steering  wheel.
# previous: Monkey had to check the wheels and the steering  wheel.
# current: Mr Croc said it was important to check  them carefully to make sure the go-kart was safe  to race.
# next: But Monkey did not listen.
#
# pre-previous: Everyone was  excited.
# previous: Monkey and Elephant lined up at the start.
# current: Mr  Croc  said  they  needed  to  listen  to  the  instructions.
# next: He  told  them  not  to go  too  fast  round the corner of the swamp.
#
# pre-previous: Mr  Croc was cross.
# previous: “Monkey needs to listen!"
# current: everyone said.
# next: Monkey was sorry that he had not listened.
#
# pre-previous: He asked Mr  Croc if everyone could help mend Monkey's go- kart.
# previous: He asked if they could race the go-karts  again when it was mended.
# current: Mr Croc said it was a  very good idea.
# next: Everyone helped to mend Monkey's go-kart.
#
# pre-previous: When it was cold he wrapped him    up in a bit of blanket.
# previous: Now and again Dave’s
# current: Mum said that Dogger was getting much too dirty.
# next: She showed Dave how to'  wash him in a bowl of soapy water.
#
# pre-previous: Next to the school gate  where the mums waited was a playing-field.
# previous: Some  men with ladders were putting up coloured flags.
# current: Mum said that there was going to be a Summer Fair  to get money to buy things for the school.
# next: Dave  pushed Dogger up against the railings to show him    what was going on.
#
# pre-previous: At tea-time Dave was rather quiet.
# previous: In the bath he was even quieter.
# current: At bed-time he said:
# next: “I want Dogger.”
#
# pre-previous: Dave began to    cry.
# previous: Bella ran after her and  tried to explain that  Dogger really belonged to  Dave, and could they    please buy him back?
# current: But the little girl said:   “No.”
# next: She said that she had  bought Dogger with her  own money
#
# pre-previous: Bella ran after her and  tried to explain that  Dogger really belonged to  Dave, and could they    please buy him back?
# previous: But the little girl said:   “No.”
# current: She said that she had  bought Dogger with her  own money
# next: and she  wanted him.
#
# pre-previous: Then Dave smiled too.
# previous: He hugged Dogger and he hugged Bella round the    waist.
# current: “Thank you, Bella,” he said.
# next: Thai night Dave had Dogger in bed beside him.
#
# pre-previous: “Shall you miss that big Teddy?”
# previous: Dave asked her.
# current: “No,” said Bella, “I didn’t like him much really.
# next: He was too big and his eyes were too staring.
#
# pre-previous: ...
# previous: kind, clever Sir Charlie Stinky Socks gave that old dragon a long cooooool drink.
# current: "Now you've stopped coughing," said the knight to the long, green dragon, "tell me what's    at the top of this tower."
# next: The dragon looked up.
#
# pre-previous: It's not a dragon's place to ask, you know -  just - to do."
# previous: “Then why don’t we find out?”
# current: said Sir Charlie with a grin.
# next: The wily witch took one last look at her watch, jumped for  joy and flew off on her broom as Charlie pushed open the    big wooden door.
#
# pre-previous: And it’s in the the middle of a deep,  dark forests, where wiggly wood wait in the grass to tickle  your toes, hungry beasties moan and monstrous trees groan…
# previous: so nobody ever comes!”
# current: "Oh, yes they do,"    said Sir Charlie, as he flung open the door.
# next: “Behold Sir Stinky Socks and his friends!”
#
# pre-previous: "
# previous: Many happy returns of the day!"
# current: he said.
# next: And everyone cheered hooray, hooray, hooray,  because that's what people do at the end of a really  big adventure.
# pre-previous: The sea    is deep and the world is wide!
# previous: How I long to sail!”
# current: Said the tiny snail.
# next: These are the other snails in the flock,  Who all stuck tight to the smooth black rock  And said to the snail with the itchy foot,  “Be quiet!
#
# pre-previous: The tiny snail
# previous: On the tail of the whale.
# ...
# next: Hippo said sorry to everyone-
#
# pre-previous: He told Miss Bird his good idea.
# previous: She  said it was a very good one.
# current: Hippo said sorry to everyone-
# next: He said sorry to Mrs Croc.
#
# pre-previous: She  said it was a very good one.
# previous: Hippo said sorry to everyone-
# current: He said sorry to Mrs Croc.
# next: He said sorry to Hattie the cat, too!
#
# pre-previous: Hippo said sorry to everyone-
# previous: He said sorry to Mrs Croc.
# current: He said sorry to Hattie the cat, too!
# next: Then Hippo asked Mrs Croc if she would help him  to bake a new chocolate cake for everyone.
#
# pre-previous: It tasted  wonderful!
# previous: Hippo was pleased.
# current: Hippo said he was glad he had owned up and  put things right.
# next: Then Mrs Croc asked him if  he would like some cake.
#
# pre-previous: Hippo said he was glad he had owned up and  put things right.
# previous: Then Mrs Croc asked him if  he would like some cake.
# current: Hippo said he did not want any.
# next: He said he did  not want any chocolate cake ever again!
#
# pre-previous: Then Mrs Croc asked him if  he would like some cake.
# previous: Hippo said he did not want any.
# current: He said he did  not want any chocolate cake ever again!
# next: Everyone laughed.
# pre-previous:  It was Monday morning
# previous: and it was Leopard's first  day at Jungle School.
# current: Miss Bird said he could sit  with Monkey, Little Lion and Giraffe.
# next: She said  Monkey, Little Lion and Giraffe could be Leopard's  friends and help him to feel welcome.
#
# pre-previous: and it was Leopard's first  day at Jungle School.
# previous: Miss Bird said he could sit  with Monkey, Little Lion and Giraffe.
# current: She said  Monkey, Little Lion and Giraffe could be Leopard's  friends and help him to feel welcome.
# next: But Giraffe was cross.
#
# pre-previous: He did not Want to make Leopard feel  welcome.
# previous: At playtime, Monkey, Little Lion and Giraffe played  football.
# current: Monkey said Leopard could play, too.
# next: But  Giraffe got cross.
#
# pre-previous: Monkey said Leopard could play, too.
# previous: But  Giraffe got cross.
# current: He said Leopard could not  play.
# next: He told Leopard to go away.
#
# pre-previous: Leopard was  sad.
# previous: He did not like being left out.
# current: Little Lion said  Giraffe was being very unkind.
# next: On Tuesday, Leopard came to school early.
#
# pre-previous: On Tuesday, Leopard came to school early.
# previous: He  was very excited.
# current: He said it was his birthday on  Saturday.
# next: He said everyone could come to his  party.
#
# pre-previous: He  was very excited.
# previous: He said it was his birthday on  Saturday.
# current: He said everyone could come to his  party.
# next: Leopard gave out lots of invitations.
#
# pre-previous: He did not like being left out.
# previous: Leopard told everyone about his party.
# current: He said it  would be good fun.
# next: He said everyone would get  party hats.
#
# pre-previous: Leopard told everyone about his party.
# previous: He said it  would be good fun.
# current: He said everyone would get  party hats.
# next: He said there would be lots of games to  play.
#
# pre-previous: He said it  would be good fun.
# previous: He said everyone would get  party hats.
# current: He said there would be lots of games to  play.
# next: He said there would be cakes, buns and jellies  to eat.
#
# pre-previous: He said everyone would get  party hats.
# previous: He said there would be lots of games to  play.
# current: He said there would be cakes, buns and jellies  to eat.
# next: He said there would be races, too.
#
# pre-previous: He said there would be lots of games to  play.
# previous: He said there would be cakes, buns and jellies  to eat.
# current: He said there would be races, too.
# next: Giraffe felt sad.
#
# pre-previous: Giraffe felt sad.
# previous: He wished he could go to Leopard's  party.
# current: But Monkey said that Giraffe had been unkind  to Leopard.
# next: Little Lion said if he had been  kinder he might not have been left out.
#
# pre-previous: He wished he could go to Leopard's  party.
# previous: But Monkey said that Giraffe had been unkind  to Leopard.
# current: Little Lion said if he had been  kinder he might not have been left out.
# next: That afternoon, Miss Bird said they had to work with  a partner to make model boats.
#
# pre-previous: But Monkey said that Giraffe had been unkind  to Leopard.
# previous: Little Lion said if he had been  kinder he might not have been left out.
# current: That afternoon, Miss Bird said they had to work with  a partner to make model boats.
# next: She said everyone  had to test the boats at the end to make sure they  floated.
#
# pre-previous: Little Lion said if he had been  kinder he might not have been left out.
# previous: That afternoon, Miss Bird said they had to work with  a partner to make model boats.
# current: She said everyone  had to test the boats at the end to make sure they  floated.
# next: She said Giraffe and Leopard had to work  together.
#
# pre-previous: That afternoon, Miss Bird said they had to work with  a partner to make model boats.
# previous: She said everyone  had to test the boats at the end to make sure they  floated.
# current: She said Giraffe and Leopard had to work  together.
# next: But Giraffe was cross.
#
# pre-previous: He told Miss Bird
# previous: he did not want to work with Leopard.
# current: He said  Leopard was not his friend.
# next: But Miss Bird did not  listen.
#
# pre-previous: But they helped each other.
# previous: Giraffe and Leopard were pleased when the boat  floated.
# current: Miss Bird said they had worked well  together.
# next: 17
#
# pre-previous: At playtime, Giraffe asked Leopard if he would like  to play football with him, Monkey and Little Lion.
# previous: They all played together.
# current: Giraffe  said  Leopard  was  a  good  player.
# next: Giraffe said he was sorry for being unkind.
#
# pre-previous: They all played together.
# previous: Giraffe  said  Leopard  was  a  good  player.
# current: Giraffe said he was sorry for being unkind.
# next: He  said he wanted to be friends.
#
# pre-previous: Giraffe  said  Leopard  was  a  good  player.
# previous: Giraffe said he was sorry for being unkind.
# current: He  said he wanted to be friends.
# next: The next day, Leopard had a surprise for  Giraffe.
#
# pre-previous: Everyone ate it  all up.
# previous: It was delicious!
# current: Then Leopard's dad said it was time to start the  races.
# next: There was a running race and a hopping  race.
#
# pre-previous: At last it was time to go home.
# previous: Everyone  thanked Leopard for a lovely party.
# current: "Let's play  together tomorrow," said Leopard.
# next: "Playing  together is fun."
#
# pre-previous: "Let's play  together tomorrow," said Leopard.
# previous: "Playing  together is fun."
# current: "Yes," said Giraffe, "but let's all  play together tomorrow.
# next: Then no one will be left  out at all.
#
# pre-previous: But one boy called Danny, a greedy young chap,  The greediest chap on the planet in fact, Was lying  awake on his mountain of toys,  Which stood even taller than most girls and boys.
# previous: But that wasn't enough, Danny still wanted more,  He wanted much more than his toy box could store.
# current: So big Santy C said, "I'll leave him a present,
# next: But this year his present might just be unpleasant?
#
# pre-previous: There, under the tree, were gifts big and small.
# previous: And a Gimungus  egg placed in front of them all.  "An egg?!"
# current: Danny said.
# next: “Santa brought me an egg?!
#
# pre-previous: The dinosaur finally gave a huge push  And pooped Danny's parents in one massive  Whooooooosh!
# previous: Last, but not least, and never forgotten, Granny  plopped out of the dinosaur's bottom.
# current: “Merry Christmas,’ said Dan to his whole family
# next: As they washed off the presents and put up the tree.
#
# pre-previous: It was a  horrid feeling.
# previous: On Friday, Miss Bird had some exciting news.
# current: She  said it was the Big Day
# next: Out in two weeks' time.
#
# pre-previous: She  said it was the Big Day
# previous: Out in two weeks' time.
# current: She  said this year they were all going to Jungle Land and  Mr Croc was going to take them in the school minibus.
# next: Everyone clapped and cheered.
#
# pre-previous: Lion's in a flap!
# previous: "
# current: everyone said.
# next: Miss Bird took Lion outside to calm down.
#
# pre-previous: Lion felt a lot better.
# previous: Then Miss Bird told Lion that everyone gets worried  sometimes.
# current: She said Lion could always talk about his  worries with his friends.
# next: Lion said that Monkey and  Hippo were his best friends.
#
# pre-previous: Then Miss Bird told Lion that everyone gets worried  sometimes.
# previous: She said Lion could always talk about his  worries with his friends.
# current: Lion said that Monkey and  Hippo were his best friends.
# next: Miss Bird said they  would be very good friends to talk to if he felt worried  again.
#
# pre-previous: She said Lion could always talk about his  worries with his friends.
# previous: Lion said that Monkey and  Hippo were his best friends.
# current: Miss Bird said they  would be very good friends to talk to if he felt worried  again.
# next: Lion felt much, much better.
#
# pre-previous: He went on  the Roaring Rocket instead and that was even  more fun!
# previous: Then Miss Bird looked at her watch.
# current: She said there  was just enough time for everyone to go on the big  drop.
# next: The Big Drop was the highest, fastest and  scariest ride in Jungle Land.
#
# pre-previous: He felt a bit better.
# previous: He  told Monkey and Hippo his worries.
# current: Monkey said the  ride could not be too high, too fast or too scary  because everyone was having lots of fun on it.
# next: Then  Hippo said that they would all sit together so that  Lion felt nice and safe.
#
# pre-previous: He  told Monkey and Hippo his worries.
# previous: Monkey said the  ride could not be too high, too fast or too scary  because everyone was having lots of fun on it.
# current: Then  Hippo said that they would all sit together so that  Lion felt nice and safe.
# next: Lion felt much better.
#
# pre-previous: “Neigh!
# previous: Neigh!”
# current: said the horse.
# next: “Want to go for a ride?”
#
# pre-previous: The spider didn’t answer.
# previous: She was very busy spinning her web.
# current: n “Moo! Moo!” said the cow.
# next: “Want to eat some grass?”
#
# pre-previous: The spider didn’t answer.
# previous: She was very busy spinning her web.
# current: n “Moo! Moo!” said the cow.
# next: “Want to eat some grass?”
#
# pre-previous: The spider didn’t answer.
# previous: She was very busy spinning her web.
# current: “Maa! Maa!” said the goat.
# next: “Want to jump on the rocks?”
# pre-previous: “Careful, Santa!” quacked the ducks.
# previous: “You nearly squashed us.”
# current: “How awful,” said Santa as he gathered    up the presents.
# next: “Sorry about that.
#
# pre-previous: he cried.
# previous: “Careful, Santa!” called the squirrel.
# current: “I am trying to be careful,” said Santa, as he struggled to    get free.
# next: Very, very slowly, Santa climbed back down again,    dropping some presents as he went.
#
# pre-previous: warned Santa’s cat.
# previous: “Eeek! I can’t stop!”
# current: said Santa, as he zoomed towards the    snowman . . .
# next: “Sorry, Snowman, I didn’t mean to bump you,” Santa said, as he  dusted himself down and popped the last of the presents into his    sack.
#
# pre-previous: “Eeek! I can’t stop!”
# previous: said Santa, as he zoomed towards the    snowman . . .
# current: “Sorry, Snowman, I didn’t mean to bump you,” Santa said, as he  dusted himself down and popped the last of the presents into his    sack.
# next: “That’s it!”
#
# pre-previous: Quickly,  Santa took off his jacket and spread    it out on the ground.
# previous: Everyone gathered round and held    the coat like a trampoline.
# current: “Hold on tight, everyone, and    don’t let go!” said Santa.
# next: “Ready, Mouse?
#
# pre-previous: their Owl Mother was  GONE.
# previous: “Where’s Mummy?” asked Sarah.
# current: “Oh my  goodness! said Percy.
# next: “I want my mummy!”
#
# pre-previous: their Owl Mother was  GONE.
# previous: “Where’s Mummy?” asked Sarah.
# current: “Oh my  goodness! said Percy.
# next: “I want my mummy!”
#
# pre-previous: “Oh my  goodness! said Percy.
# previous: “I want my mummy!”
# current: said  Bill.
# next: The baby owls thought  (all owls think a lot) -
#
# pre-previous: said  Bill.
# previous: The baby owls thought  (all owls think a lot) -
# current: “I think she’s gone hunting, said Sarah.
# next: “To get us our food! said Percy.
#
# pre-previous: The baby owls thought  (all owls think a lot) -
# previous: “I think she’s gone hunting, said Sarah.
# current: “To get us our food! said Percy.
# next: “I want my mummy! said Bill.
#
# pre-previous: “I think she’s gone hunting, said Sarah.
# previous: “To get us our food! said Percy.
# current: “I want my mummy! said Bill.
# next: > -
#
# pre-previous: and they sat on the tree and  waited.
# previous: A big branch for Sarah, a small branch for Percy,  and an old bit of ivy for Bill.
# current: “She’ll be back,” said  Sarah.
# next: “Back soon!” said Percy.
#
# pre-previous: A big branch for Sarah, a small branch for Percy,  and an old bit of ivy for Bill.
# previous: “She’ll be back,” said  Sarah.
# current: “Back soon!” said Percy.
# next: “I want my  mummy!” said Bill.
#
# pre-previous: “She’ll be back,” said  Sarah.
# previous: “Back soon!” said Percy.
# current: “I want my  mummy!” said Bill.
# next: 9
#
# pre-previous: ~  ‘ It was dark in the wood and they had to be brave,  for things
# previous: moved all around them.
# current: “She’ll bring us  mice and things that are nice,” said Sarah.
# next: “I suppose so!” said Percy.
#
# pre-previous: moved all around them.
# previous: “She’ll bring us  mice and things that are nice,” said Sarah.
# current: “I suppose so!” said Percy.
# next: “I want my mummy!” said Bill.
#
# pre-previous: “She’ll bring us  mice and things that are nice,” said Sarah.
# previous: “I suppose so!” said Percy.
# current: “I want my mummy!” said Bill.
# next: They sat and they thought (all owls think a lot) -
#
# pre-previous: “I want my mummy!” said Bill.
# previous: They sat and they thought (all owls think a lot) -
# current: “I  think we should all  sit on my branch,” said Sarah.
# next: And they did, all  three together.
#
# pre-previous: “I  think we should all  sit on my branch,” said Sarah.
# previous: And they did, all  three together.
# current: “Suppose she got lost,” said Sarah.
# next: “Or a fox got her!”
#
# pre-previous: “Suppose she got lost,” said Sarah.
# previous: “Or a fox got her!”
# current: said Percy.
# next: I want my mummy!” said Bill.
#
# pre-previous: “Or a fox got her!”
# previous: said Percy.
# current: I want my mummy!” said Bill.
# next: And  the baby owls closed their owl eyes  and wished their Owl Mother would  come.
#
# pre-previous: The baby owls thought
# previous: (all owls think a lot) -
# current: “I knew it,” said Sarah.
# next: “And I knew it!”
#
# pre-previous: “I knew it,” said Sarah.
# previous: “And I knew it!”
# current: said Percy.
# next: “I love my mummy!” said Bill.
#
# pre-previous: “And I knew it!”
# previous: said Percy.
# current: “I love my mummy!” said Bill.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-b87d8d0cbe69> in <module>
#      14                     print('previous:', sentence_list[sentence_list.index(possible_subject.sent)-1])
#      15                     print('current:', possible_subject.head.sent)
# ---> 16                     print('next:', sentence_list[sentence_list.index(possible_subject.sent)+1])
#      17                     print(' ')
#      18
#
# IndexError: list index out of range

# %%
from unidecode import unidecode

# %%
for title, text in zip(df.Title, df.Text):
    text = text.replace('\n', ' ')
    doc = nlp(text)
    sentence_list = list(doc.sents)
    break

# %%
test=[s for s in sentence_list if 's Snake' in str(s)][0]

# %%
unidecode(str(test))
# Out:
# '"It\'s Snake," said the mouse.'
